# %% [markdown]
# #Pemrograman Tugas Akhir:
#
#
# "Segmentasi Burned Area menggunakan Model U-Net pada Citra Landsat 9 (Studi Kasus: Sumatera Selatan)"
#
#
# *   Data Preprocessing
#     * Koreksi Atmosferik (Dark Object Substraction)
#     * Cloud Masking (QA Bands)
#     * Komposit Citra (False Color)
# *   Ekstraksi Fitur
#     * NDVI
#     * NBR
#     * dNBR
# *   Band Stacking
# *   Masking Citra
#
#
#
# Tools & Platform
#
# ![Google Earth Engine](https://img.shields.io/badge/-GEE-34A853?style=flat&logo=google-earth&logoColor=white)  ![Pandas](https://img.shields.io/badge/-Pandas-150458?style=flat&logo=pandas&logoColor=white)  ![Folium](https://img.shields.io/badge/-Folium-77B829?style=flat&logo=leaflet&logoColor=white)  ![geemap](https://img.shields.io/badge/-geemap-34A853?style=flat&logo=googleearth&logoColor=white)

# %% [markdown]
# # Inisialisasi dan Authentikasi GEE

# %%
import ee
ee.Authenticate() #Authentikasi GEE
ee.Initialize(project='ee-analafeanalber9') #Inisialisasi GEE dengan ID Project GEE

# %% [markdown]
# # Data Description (Data Raw)

# %% [markdown]
# ## Prefire (01-01-2023 until 31-07-2023)

# %%
import ee
import pandas as pd

#Inisiasi Pathrow dan rentang waktu data digunakan
path = 124
row = 62
start_date = '2023-01-01'
end_date = '2023-07-31'

#Memanggil Koleksi Citra berdasarkan pathrow dan rentang waktu data
landsat9_col = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(ee.Filter.eq('WRS_PATH', path)) \
    .filter(ee.Filter.eq('WRS_ROW', row)) \
    .filterDate(start_date, end_date)

#Memberikan informasi tanggal citra tersedia, persentas cloud cover serta id citra
dates = landsat9_col.aggregate_array('DATE_ACQUIRED').getInfo()
clouds = landsat9_col.aggregate_array('CLOUD_COVER').getInfo()
ids = landsat9_col.aggregate_array('LANDSAT_PRODUCT_ID').getInfo()


#Fungsi membuat dataframe
if dates:
    df = pd.DataFrame({
        'Pathrow': 124062,
        'Kondisi': 'Prefire',
        'Tanggal Citra': dates,
        'Cloud Cover (%)': clouds,
        'Product ID': ids
    })
    df
else:
    print("Tidak ada citra tersedia pada rentang waktu dan path/row tersebut.")

#Menampilkan dataframe sort berdasarkan cloud cover persentase terkecil ke terbesar
df = df.sort_values(by='Cloud Cover (%)', ascending=True).reset_index(drop=True)
df
# Out:
#     Pathrow  Kondisi Tanggal Citra  Cloud Cover (%)  \
# 0    124062  Prefire    2023-07-26            14.07
# 1    124062  Prefire    2023-04-21            29.16
# 2    124062  Prefire    2023-06-24            33.04
# 3    124062  Prefire    2023-03-20            54.76
# 4    124062  Prefire    2023-04-05            56.74
# 5    124062  Prefire    2023-05-23            57.75
# 6    124062  Prefire    2023-07-10            83.95
# 7    124062  Prefire    2023-01-15            84.48
# 8    124062  Prefire    2023-02-16            86.69
# 9    124062  Prefire    2023-06-08            93.87
# 10   124062  Prefire    2023-05-07           100.00
# 11   124062  Prefire    2023-03-04           100.00
#
#                                   Product ID
# 0   LC09_L1TP_124062_20230726_20230726_02_T1
# 1   LC09_L1TP_124062_20230421_20230421_02_T1
# 2   LC09_L1TP_124062_20230624_20230624_02_T1
# 3   LC09_L1TP_124062_20230320_20230320_02_T1
# 4   LC09_L1TP_124062_20230405_20230405_02_T1
# 5   LC09_L1TP_124062_20230523_20230523_02_T1
# 6   LC09_L1TP_124062_20230710_20230710_02_T1
# 7   LC09_L1TP_124062_20230115_20230313_02_T1
# 8   LC09_L1TP_124062_20230216_20230310_02_T1
# 9   LC09_L1TP_124062_20230608_20230608_02_T1
# 10  LC09_L1TP_124062_20230507_20230507_02_T1
# 11  LC09_L1TP_124062_20230304_20230307_02_T1

# %%
import ee
import folium
import geemap.foliumap as geemap

#Fungsi folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

# Filter Path/Row dan Tanggal
path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-01-01'
end_date = '2023-07-31'

#Akses koleksi citra
landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()

#metadata tanggal dan cloud cover
date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')

#Visualisasi Band
band5_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band7_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band4_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'red', 'darkred']
}


#Peta Interaktif
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(landsat9_toa.select('B7'), band7_vis_params, 'Band 7 (SWIR)')
m.add_ee_layer(landsat9_toa.select('B5'), band5_vis_params, 'Band 5 (NIR)')
m.add_ee_layer(landsat9_toa.select('B4'), band4_vis_params, 'Band 4 (RED)')

#Kontrol layer
m.add_child(folium.LayerControl())

#Tambahkan info di atas peta
title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Pathrow 124062 (Prefire)
     </b></h3>
     <h3 align="center" style="font-size:16px"><b>
     Tanggal Citra: {date_acquired} | Cloud Cover: {cloud_cover}%
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
# Citra yang ditampilkan diambil pada tanggal: 2023-07-26
# Persentase Cloud Cover: 14.07%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ca192c348f6459e54f4e7edf43ba748 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Pathrow 124062 (Prefire)
#      &lt;/b&gt;&lt;/h3&gt;
#      &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;
#      Tanggal Citra: 2023-07-26 | Cloud Cover: 14.07%
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ca192c348f6459e54f4e7edf43ba748&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6ca192c348f6459e54f4e7edf43ba748 = L.map(
#                 &quot;map_6ca192c348f6459e54f4e7edf43ba748&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_338f1842c76f20613d861090b7a52534 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_338f1842c76f20613d861090b7a52534.addTo(map_6ca192c348f6459e54f4e7edf43ba748);
#
#
#             var tile_layer_794d94fe1efe6c520295de6a263fbbdb = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/ffd838e224c9c5fd767af964c7820ba1-a18f589417b48a46557d7d669ea2f6a1/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_794d94fe1efe6c520295de6a263fbbdb.addTo(map_6ca192c348f6459e54f4e7edf43ba748);
#
#
#             var tile_layer_44c720b9b29d7d9b4e3d8937cf2c1da9 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/4901e91b815cbeeeb00347cd2ff59e9a-a6cbb44e255f7cbf6cceb1ddb9a4b31c/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_44c720b9b29d7d9b4e3d8937cf2c1da9.addTo(map_6ca192c348f6459e54f4e7edf43ba748);
#
#
#             var tile_layer_07ce2b7124bc47e8bdec2b25a90148d3 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/ac008255279a6c49124b8a91c35fd543-c4f85cbe8ea087f60dbd5511b6191ea0/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07ce2b7124bc47e8bdec2b25a90148d3.addTo(map_6ca192c348f6459e54f4e7edf43ba748);
#
#
#             var layer_control_12241b2a86ed983f47c10ad29e30861b_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_338f1842c76f20613d861090b7a52534,
#                 },
#                 overlays :  {
#                     &quot;Band 7 (SWIR)&quot; : tile_layer_794d94fe1efe6c520295de6a263fbbdb,
#                     &quot;Band 5 (NIR)&quot; : tile_layer_44c720b9b29d7d9b4e3d8937cf2c1da9,
#                     &quot;Band 4 (RED)&quot; : tile_layer_07ce2b7124bc47e8bdec2b25a90148d3,
#                 },
#             };
#             let layer_control_12241b2a86ed983f47c10ad29e30861b = L.control.layers(
#                 layer_control_12241b2a86ed983f47c10ad29e30861b_layers.base_layers,
#                 layer_control_12241b2a86ed983f47c10ad29e30861b_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_6ca192c348f6459e54f4e7edf43ba748);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import ee
import pandas as pd

path = 125
row = 62
start_date = '2023-01-01'
end_date = '2023-07-31'


landsat9_col = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(ee.Filter.eq('WRS_PATH', path)) \
    .filter(ee.Filter.eq('WRS_ROW', row)) \
    .filterDate(start_date, end_date)


dates = landsat9_col.aggregate_array('DATE_ACQUIRED').getInfo()
clouds = landsat9_col.aggregate_array('CLOUD_COVER').getInfo()
ids = landsat9_col.aggregate_array('LANDSAT_PRODUCT_ID').getInfo()


if dates:
    df = pd.DataFrame({
        'Pathrow': 125062,
        'Kondisi': 'Prefire',
        'Tanggal Citra': dates,
        'Cloud Cover (%)': clouds,
        'Product ID': ids
    })
    df
else:
    print("Tidak ada citra tersedia pada rentang waktu dan path/row tersebut.")

df = df.sort_values(by='Cloud Cover (%)', ascending=True).reset_index(drop=True)
df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     Pathrow  Kondisi Tanggal Citra  Cloud Cover (%)  \
# 0    125062  Prefire    2023-05-14            26.38
# 1    125062  Prefire    2023-01-22            50.78
# 2    125062  Prefire    2023-06-15            65.17
# 3    125062  Prefire    2023-04-12            66.80
# 4    125062  Prefire    2023-01-06            73.91
# 5    125062  Prefire    2023-04-28            75.61
# 6    125062  Prefire    2023-02-07            87.14
# 7    125062  Prefire    2023-07-01            90.50
# 8    125062  Prefire    2023-05-30            91.37
# 9    125062  Prefire    2023-03-27            92.76
# 10   125062  Prefire    2023-07-17            95.70
#
#                                   Product ID
# 0   LC09_L1TP_125062_20230514_20230514_02_T1
# 1   LC09_L1TP_125062_20230122_20230313_02_T1
# 2   LC09_L1TP_125062_20230615_20230615_02_T1
# 3   LC09_L1TP_125062_20230412_20230412_02_T1
# 4   LC09_L1TP_125062_20230106_20230314_02_T1
# 5   LC09_L1TP_125062_20230428_20230428_02_T1
# 6   LC09_L1TP_125062_20230207_20230310_02_T1
# 7   LC09_L1TP_125062_20230701_20230701_02_T1
# 8   LC09_L1TP_125062_20230530_20230530_02_T1
# 9   LC09_L1TP_125062_20230327_20230327_02_T1
# 10  LC09_L1TP_125062_20230717_20230717_02_T1

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

start_date = '2023-01-01'
end_date = '2023-07-31'

landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()

date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')

band5_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band7_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band4_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'red', 'darkred']
}


#Peta Interaktif
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(landsat9_toa.select('B7'), band7_vis_params, 'Band 7 (SWIR)')
m.add_ee_layer(landsat9_toa.select('B5'), band5_vis_params, 'Band 5 (NIR)')
m.add_ee_layer(landsat9_toa.select('B4'), band4_vis_params, 'Band 4 (RED)')
#Kontrol layer
m.add_child(folium.LayerControl())

#Tambahkan info di atas peta
title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Pathrow 125062 (Prefire)
     </b></h3>

     <h3 align="center" style="font-size:16px"><b>
     Tanggal Citra: {date_acquired} | Cloud Cover: {cloud_cover}%
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Citra yang ditampilkan diambil pada tanggal: 2023-05-14
# Persentase Cloud Cover: 26.38%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa7efb2150ac8eebe8657401d60c84a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Pathrow 125062 (Prefire)
#      &lt;/b&gt;&lt;/h3&gt;
#
#      &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;
#      Tanggal Citra: 2023-05-14 | Cloud Cover: 26.38%
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa7efb2150ac8eebe8657401d60c84a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa7efb2150ac8eebe8657401d60c84a1 = L.map(
#                 &quot;map_aa7efb2150ac8eebe8657401d60c84a1&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4df6803d59d537d244c198fbf20ad9ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4df6803d59d537d244c198fbf20ad9ab.addTo(map_aa7efb2150ac8eebe8657401d60c84a1);
#
#
#             var tile_layer_265bdc5ec21ed471119a6c88671f8979 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/4e57a178e044294c85a039b78c60aa08-82f187dd675ca77b79e9bc022a290c17/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_265bdc5ec21ed471119a6c88671f8979.addTo(map_aa7efb2150ac8eebe8657401d60c84a1);
#
#
#             var tile_layer_bcd44105cc12f0416583b06993757432 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/4f7df333b0e3ebced692f721c80a518e-47415f74a99389a08df4c8a3ee8e683b/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bcd44105cc12f0416583b06993757432.addTo(map_aa7efb2150ac8eebe8657401d60c84a1);
#
#
#             var tile_layer_6cfb7a1d3ba6e5de249b00fd0f2f6937 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/0ecb6f96e801adbaddb398984f260554-4b1578b99efa3618256621ae540fe7a3/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6cfb7a1d3ba6e5de249b00fd0f2f6937.addTo(map_aa7efb2150ac8eebe8657401d60c84a1);
#
#
#             var layer_control_34558c98659f9a5a01105fd9c52ad558_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_4df6803d59d537d244c198fbf20ad9ab,
#                 },
#                 overlays :  {
#                     &quot;Band 7 (SWIR)&quot; : tile_layer_265bdc5ec21ed471119a6c88671f8979,
#                     &quot;Band 5 (NIR)&quot; : tile_layer_bcd44105cc12f0416583b06993757432,
#                     &quot;Band 4 (RED)&quot; : tile_layer_6cfb7a1d3ba6e5de249b00fd0f2f6937,
#                 },
#             };
#             let layer_control_34558c98659f9a5a01105fd9c52ad558 = L.control.layers(
#                 layer_control_34558c98659f9a5a01105fd9c52ad558_layers.base_layers,
#                 layer_control_34558c98659f9a5a01105fd9c52ad558_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_aa7efb2150ac8eebe8657401d60c84a1);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Postfire (01-11-2023 until 31-12-2023

# %%
import ee
import pandas as pd

path = 124
row = 62
start_date = '2023-11-01'
end_date = '2023-12-31'

landsat9_col = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(ee.Filter.eq('WRS_PATH', path)) \
    .filter(ee.Filter.eq('WRS_ROW', row)) \
    .filterDate(start_date, end_date)

dates = landsat9_col.aggregate_array('DATE_ACQUIRED').getInfo()
clouds = landsat9_col.aggregate_array('CLOUD_COVER').getInfo()
ids = landsat9_col.aggregate_array('LANDSAT_PRODUCT_ID').getInfo()

if dates:
    df = pd.DataFrame({
        'Pathrow': 124062,
        'Kondisi': 'Postfire',
        'Tanggal Citra': dates,
        'Cloud Cover (%)': clouds,
        'Product ID': ids
    })
    df
else:
    print("Tidak ada citra tersedia pada rentang waktu dan path/row tersebut.")

df = df.sort_values(by='Cloud Cover (%)', ascending=True).reset_index(drop=True)
df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    Pathrow   Kondisi Tanggal Citra  Cloud Cover (%)  \
# 0   124062  Postfire    2023-11-15            23.63
# 1   124062  Postfire    2023-12-17            69.01
#
#                                  Product ID
# 0  LC09_L1TP_124062_20231115_20231115_02_T1
# 1  LC09_L1TP_124062_20231217_20231217_02_T1

# %%
import ee
import folium
import geemap.foliumap as geemap


def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

start_date = '2023-11-01'
end_date = '2023-12-31'


landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()


date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')


band5_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band7_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band4_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'red', 'darkred']
}


m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(landsat9_toa.select('B7'), band7_vis_params, 'Band 7 (SWIR)')
m.add_ee_layer(landsat9_toa.select('B5'), band5_vis_params, 'Band 5 (NIR)')
m.add_ee_layer(landsat9_toa.select('B4'), band4_vis_params, 'Band 4 (RED)')
m.add_child(folium.LayerControl())

title_html = f'''
<h3 align="center" style="font-size:20px"><b>
     Pathrow 124062 (Postfire)
     </b></h3>
     <h3 align="center" style="font-size:16px"><b>
     Tanggal Citra: {date_acquired} | Cloud Cover: {cloud_cover}%
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Citra yang ditampilkan diambil pada tanggal: 2023-11-15
# Persentase Cloud Cover: 23.63%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7aa78fd88faac48421a3cc155fb30e26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Pathrow 124062 (Postfire)
#      &lt;/b&gt;&lt;/h3&gt;
#      &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;
#      Tanggal Citra: 2023-11-15 | Cloud Cover: 23.63%
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7aa78fd88faac48421a3cc155fb30e26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7aa78fd88faac48421a3cc155fb30e26 = L.map(
#                 &quot;map_7aa78fd88faac48421a3cc155fb30e26&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce2f754d2dd2e56eb476dff3564551c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce2f754d2dd2e56eb476dff3564551c8.addTo(map_7aa78fd88faac48421a3cc155fb30e26);
#
#
#             var tile_layer_ec39510a7b3a0a19e63ffb4e3d4f00c6 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/bc8bb06931965b6cdb09e37d8fe74e0f-e6c92b9e5d622f121d540b5e32b50e6c/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec39510a7b3a0a19e63ffb4e3d4f00c6.addTo(map_7aa78fd88faac48421a3cc155fb30e26);
#
#
#             var tile_layer_1c33b4eba06bd1672053b6f7f53d5253 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/6979d81ae8c3d1460dd9b3bf7aaf704b-1e911c8b2275e2123da2aab5345a9080/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c33b4eba06bd1672053b6f7f53d5253.addTo(map_7aa78fd88faac48421a3cc155fb30e26);
#
#
#             var tile_layer_5ca0a6350f4c7a2691b97c815b217f4e = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/64c7856d46d0e88ad11ad9aff6df08d5-8a2c70025b1c103bf3e0ed5224b642b1/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ca0a6350f4c7a2691b97c815b217f4e.addTo(map_7aa78fd88faac48421a3cc155fb30e26);
#
#
#             var layer_control_fd6fefb3e7d5f78869c5ef2b675259ad_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_ce2f754d2dd2e56eb476dff3564551c8,
#                 },
#                 overlays :  {
#                     &quot;Band 7 (SWIR)&quot; : tile_layer_ec39510a7b3a0a19e63ffb4e3d4f00c6,
#                     &quot;Band 5 (NIR)&quot; : tile_layer_1c33b4eba06bd1672053b6f7f53d5253,
#                     &quot;Band 4 (RED)&quot; : tile_layer_5ca0a6350f4c7a2691b97c815b217f4e,
#                 },
#             };
#             let layer_control_fd6fefb3e7d5f78869c5ef2b675259ad = L.control.layers(
#                 layer_control_fd6fefb3e7d5f78869c5ef2b675259ad_layers.base_layers,
#                 layer_control_fd6fefb3e7d5f78869c5ef2b675259ad_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_7aa78fd88faac48421a3cc155fb30e26);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import ee
import pandas as pd

path = 125
row = 62
start_date = '2023-11-01'
end_date = '2023-12-31'

landsat9_col = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(ee.Filter.eq('WRS_PATH', path)) \
    .filter(ee.Filter.eq('WRS_ROW', row)) \
    .filterDate(start_date, end_date)

dates = landsat9_col.aggregate_array('DATE_ACQUIRED').getInfo()
clouds = landsat9_col.aggregate_array('CLOUD_COVER').getInfo()
ids = landsat9_col.aggregate_array('LANDSAT_PRODUCT_ID').getInfo()

# Buat DataFrame
if dates:
    df = pd.DataFrame({
        'Pathrow': 125062,
        'Kondisi': 'Postfire',
        'Tanggal Citra': dates,
        'Cloud Cover (%)': clouds,
        'Product ID': ids
    })
    df
else:
    print("Tidak ada citra tersedia pada rentang waktu dan path/row tersebut.")

df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    Pathrow   Kondisi Tanggal Citra  Cloud Cover (%)  \
# 0   125062  Postfire    2023-11-06            41.67
# 1   125062  Postfire    2023-11-22            92.79
# 2   125062  Postfire    2023-12-08            69.28
# 3   125062  Postfire    2023-12-24           100.00
#
#                                  Product ID
# 0  LC09_L1TP_125062_20231106_20231106_02_T1
# 1  LC09_L1TP_125062_20231122_20231122_02_T1
# 2  LC09_L1TP_125062_20231208_20231208_02_T1
# 3  LC09_L1TP_125062_20231224_20231224_02_T1

# %%
import ee
import folium
import geemap.foliumap as geemap


def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

start_date = '2023-11-01'
end_date = '2023-12-31'

landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()

date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')

band5_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band7_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band4_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'red', 'darkred']
}



m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(landsat9_toa.select('B7'), band7_vis_params, 'Band 7 (SWIR)')
m.add_ee_layer(landsat9_toa.select('B5'), band5_vis_params, 'Band 5 (NIR)')
m.add_ee_layer(landsat9_toa.select('B4'), band4_vis_params, 'Band 4 (RED)')
m.add_child(folium.LayerControl())

title_html = f'''
  <h3 align="center" style="font-size:20px"><b>
     Pathrow 125062 (Postfire)
     </b></h3>
     <h3 align="center" style="font-size:16px"><b>
     Tanggal Citra: {date_acquired} | Cloud Cover: {cloud_cover}%
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Citra yang ditampilkan diambil pada tanggal: 2023-11-06
# Persentase Cloud Cover: 41.67%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a58c131e80c62a0173cf902f0b608a2e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#   &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Pathrow 125062 (Postfire)
#      &lt;/b&gt;&lt;/h3&gt;
#      &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;
#      Tanggal Citra: 2023-11-06 | Cloud Cover: 41.67%
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a58c131e80c62a0173cf902f0b608a2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a58c131e80c62a0173cf902f0b608a2e = L.map(
#                 &quot;map_a58c131e80c62a0173cf902f0b608a2e&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1a3995f10b747f441e34eacb7bfd37e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b1a3995f10b747f441e34eacb7bfd37e.addTo(map_a58c131e80c62a0173cf902f0b608a2e);
#
#
#             var tile_layer_df42a8d1383dfa8e3f62a2db928d9d32 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/7a1c31d690f9b8d500649d86e5c0c399-f786927dc2d52ea8a0d394735a7c0052/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df42a8d1383dfa8e3f62a2db928d9d32.addTo(map_a58c131e80c62a0173cf902f0b608a2e);
#
#
#             var tile_layer_fc7c4a15a393ef5741ef4387dffb1e1b = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/4873acecc96a0222e4e42e2ea4f1125d-8d44a8003c7faec71eee89ff911467cb/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fc7c4a15a393ef5741ef4387dffb1e1b.addTo(map_a58c131e80c62a0173cf902f0b608a2e);
#
#
#             var tile_layer_bbe702506f56ef3d7b775d51c4888eed = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/e97e2a50b70521abdbf3eca072588862-a0b2534fc7733787cb5f5f6bd96d3b3a/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bbe702506f56ef3d7b775d51c4888eed.addTo(map_a58c131e80c62a0173cf902f0b608a2e);
#
#
#             var layer_control_4a8dd8883c98421182ba8cfb18b436dd_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_b1a3995f10b747f441e34eacb7bfd37e,
#                 },
#                 overlays :  {
#                     &quot;Band 7 (SWIR)&quot; : tile_layer_df42a8d1383dfa8e3f62a2db928d9d32,
#                     &quot;Band 5 (NIR)&quot; : tile_layer_fc7c4a15a393ef5741ef4387dffb1e1b,
#                     &quot;Band 4 (RED)&quot; : tile_layer_bbe702506f56ef3d7b775d51c4888eed,
#                 },
#             };
#             let layer_control_4a8dd8883c98421182ba8cfb18b436dd = L.control.layers(
#                 layer_control_4a8dd8883c98421182ba8cfb18b436dd_layers.base_layers,
#                 layer_control_4a8dd8883c98421182ba8cfb18b436dd_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_a58c131e80c62a0173cf902f0b608a2e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Koreksi Atmosferik

# %% [markdown]
# ### Pathrow 124062 (Prefire)

# %%
import ee
import folium
import geemap.foliumap as geemap

#Fungsi agar folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)  #Mengambil URL peta dari objek citra EE dengan visualisasi tertentu

     #Menambahkan layer citra EE ke peta Folium menggunakan TileLayer
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format, # URL tile GEE
        attr='Google Earth Engine', #Atribut sumber tile
        name=name, #Nama layer untuk kontrol layer di peta
        overlay=True, #Menandakan ini layer tambahan, bukan base map
        control=True  #Memungkinkan kontrol layer aktif/nonaktif
    ).add_to(self) #Menambahkan layer ke map
folium.Map.add_ee_layer = add_ee_layer


#Filter Path/Row dan Tanggal
path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-01-01'
end_date = '2023-07-31'

#Ambil citra dari koleksi berdasarkan cloud cover terkecil
landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()

#Ambil metadata tanggal dan cloud cover
date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')

#DARK OBJECT SUBTRACTION (DOS)
def dark_object_subtraction(img, band_names): #memanggil band names di dark_object_substractiobn (B7,B5,B4)
    def subtract_min(band_name):
        band = img.select(band_name) #Memilih band tertentu
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),  #mendekati nilai minimum (nilai persentil 1)
            geometry=band.geometry(), #geometri dari band
            scale=30, #skala resolusi 30meter
            maxPixels=1e9 #batas max pixel dihitung
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name) # Mengurangi seluruh nilai band dengan nilai dark object, hasilnya direturn sebagai band baru
    corrected_bands = [subtract_min(b) for b in band_names]  #hasilnya berupa list band yang sudah dikoreksi
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames()) # Menggabungkan semua band hasil koreksi menjadi satu citra baru, dan menyalin properti metadata dari citra asli

#menjalankan fungsi dark_object_subtraction, dengan inputan citra landsat9_toa dan list band
dos_corrected = dark_object_subtraction(landsat9_toa, ['B7', 'B5', 'B4'])


#Visualisasi citra di GEEMAP
false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'DOS False Color (B7-B5-B4)')
m.add_child(folium.LayerControl()) # Kontrol layer


#informasi tanggal dan cloud cover di atas peta
title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Koreksi Atmosferik (DOS) | Pathrow 124062 | Prefire
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Citra yang ditampilkan diambil pada tanggal: 2023-07-26
# Persentase Cloud Cover: 14.07%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b21f0bdc01d9683d2ed761e133872a93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Koreksi Atmosferik (DOS) | Pathrow 124062 | Prefire
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b21f0bdc01d9683d2ed761e133872a93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b21f0bdc01d9683d2ed761e133872a93 = L.map(
#                 &quot;map_b21f0bdc01d9683d2ed761e133872a93&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec958fe45b29c0dd0e6b3b8574483d2c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec958fe45b29c0dd0e6b3b8574483d2c.addTo(map_b21f0bdc01d9683d2ed761e133872a93);
#
#
#             var tile_layer_a80dbb67893b567c06e93101dccd9e1e = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/e74bb5e2225eab9de7f2aaeed6109745-ade10727bad419c465c5b91e59e68207/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a80dbb67893b567c06e93101dccd9e1e.addTo(map_b21f0bdc01d9683d2ed761e133872a93);
#
#
#             var layer_control_58d8841077a5146d7811b56ac4e261ba_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_ec958fe45b29c0dd0e6b3b8574483d2c,
#                 },
#                 overlays :  {
#                     &quot;DOS False Color (B7-B5-B4)&quot; : tile_layer_a80dbb67893b567c06e93101dccd9e1e,
#                 },
#             };
#             let layer_control_58d8841077a5146d7811b56ac4e261ba = L.control.layers(
#                 layer_control_58d8841077a5146d7811b56ac4e261ba_layers.base_layers,
#                 layer_control_58d8841077a5146d7811b56ac4e261ba_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_b21f0bdc01d9683d2ed761e133872a93);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Pathrow 125062 (Prefire)

# %%
import ee
import folium
import geemap.foliumap as geemap


def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-01-01'
end_date = '2023-07-31'


landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()


date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')


def dark_object_subtraction(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),  # mendekati nilai minimum
            geometry=band.geometry(),
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)

    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())


dos_corrected = dark_object_subtraction(landsat9_toa, ['B7', 'B5', 'B4'])


false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}


m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'DOS False Color (B7-B5-B4)')
m.add_child(folium.LayerControl())


title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Koreksi Atmosferik (DOS) | Pathrow 125062 | Prefire
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Citra yang ditampilkan diambil pada tanggal: 2023-05-14
# Persentase Cloud Cover: 26.38%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f071851c80862cc24e14226f7d69d211 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Koreksi Atmosferik (DOS) | Pathrow 125062 | Prefire
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f071851c80862cc24e14226f7d69d211&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f071851c80862cc24e14226f7d69d211 = L.map(
#                 &quot;map_f071851c80862cc24e14226f7d69d211&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_695b24722466e493c1af8b6d93d3528b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_695b24722466e493c1af8b6d93d3528b.addTo(map_f071851c80862cc24e14226f7d69d211);
#
#
#             var tile_layer_c559efd136092e2cdd04ca5bd97645ef = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/8cfa3de488d936a49111258ac0bd18d5-76dc1166fb4a4254ec9683d610360a5b/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c559efd136092e2cdd04ca5bd97645ef.addTo(map_f071851c80862cc24e14226f7d69d211);
#
#
#             var layer_control_758c84b5a71a0ced74ba3f0ffd3a073b_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_695b24722466e493c1af8b6d93d3528b,
#                 },
#                 overlays :  {
#                     &quot;DOS False Color (B7-B5-B4)&quot; : tile_layer_c559efd136092e2cdd04ca5bd97645ef,
#                 },
#             };
#             let layer_control_758c84b5a71a0ced74ba3f0ffd3a073b = L.control.layers(
#                 layer_control_758c84b5a71a0ced74ba3f0ffd3a073b_layers.base_layers,
#                 layer_control_758c84b5a71a0ced74ba3f0ffd3a073b_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_f071851c80862cc24e14226f7d69d211);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Pathrow 124062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap


def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'


landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()


date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')


def dark_object_subtraction(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),  # mendekati nilai minimum
            geometry=band.geometry(),
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

dos_corrected = dark_object_subtraction(landsat9_toa, ['B7', 'B5', 'B4'])

false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}


m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'DOS False Color (B7-B5-B4)')
m.add_child(folium.LayerControl())


title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Koreksi Atmosferik (DOS) | Pathrow 124062 | Postfire
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Citra yang ditampilkan diambil pada tanggal: 2023-11-15
# Persentase Cloud Cover: 23.63%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c9807fd73cd4b8a4649a9de107fa62a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Koreksi Atmosferik (DOS) | Pathrow 124062 | Postfire
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c9807fd73cd4b8a4649a9de107fa62a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c9807fd73cd4b8a4649a9de107fa62a = L.map(
#                 &quot;map_1c9807fd73cd4b8a4649a9de107fa62a&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53bea0fc642f17d20185c1edc934332b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53bea0fc642f17d20185c1edc934332b.addTo(map_1c9807fd73cd4b8a4649a9de107fa62a);
#
#
#             var tile_layer_f5085ae978917e714429a57f031de39e = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/93bbef1299e5704568704b82fa077f59-9d2c567de7370c6cc722f4958dceba1e/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f5085ae978917e714429a57f031de39e.addTo(map_1c9807fd73cd4b8a4649a9de107fa62a);
#
#
#             var layer_control_b6a2db7f9a1d5a0c3782069c4bcc90d9_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_53bea0fc642f17d20185c1edc934332b,
#                 },
#                 overlays :  {
#                     &quot;DOS False Color (B7-B5-B4)&quot; : tile_layer_f5085ae978917e714429a57f031de39e,
#                 },
#             };
#             let layer_control_b6a2db7f9a1d5a0c3782069c4bcc90d9 = L.control.layers(
#                 layer_control_b6a2db7f9a1d5a0c3782069c4bcc90d9_layers.base_layers,
#                 layer_control_b6a2db7f9a1d5a0c3782069c4bcc90d9_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_1c9807fd73cd4b8a4649a9de107fa62a);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Pathrow 125062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap


def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

start_date = '2023-11-01'
end_date = '2023-12-31'


landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()


date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')


def dark_object_subtraction(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),  # mendekati nilai minimum
            geometry=band.geometry(),
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

dos_corrected = dark_object_subtraction(landsat9_toa, ['B7', 'B5', 'B4'])


false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}


m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'DOS False Color (B7-B5-B4)')
m.add_child(folium.LayerControl())


title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Koreksi Atmosferik (DOS) | Pathrow 125062 | Postfire
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Citra yang ditampilkan diambil pada tanggal: 2023-11-06
# Persentase Cloud Cover: 41.67%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8fa09b857645eef1360d05127a03f12 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Koreksi Atmosferik (DOS) | Pathrow 125062 | Postfire
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8fa09b857645eef1360d05127a03f12&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8fa09b857645eef1360d05127a03f12 = L.map(
#                 &quot;map_c8fa09b857645eef1360d05127a03f12&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_abb614099aaf3aa85f1fe3e3277ab2ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_abb614099aaf3aa85f1fe3e3277ab2ab.addTo(map_c8fa09b857645eef1360d05127a03f12);
#
#
#             var tile_layer_ed804b111fd2b64f9fbc832821936bfd = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/ec4901084263f36d723a369943c56a40-9d8ad54a9ddbd4d4600f6c251ea8c6c2/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed804b111fd2b64f9fbc832821936bfd.addTo(map_c8fa09b857645eef1360d05127a03f12);
#
#
#             var layer_control_c665de7a9c0e87dd4356bdf537cbc0ce_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_abb614099aaf3aa85f1fe3e3277ab2ab,
#                 },
#                 overlays :  {
#                     &quot;DOS False Color (B7-B5-B4)&quot; : tile_layer_ed804b111fd2b64f9fbc832821936bfd,
#                 },
#             };
#             let layer_control_c665de7a9c0e87dd4356bdf537cbc0ce = L.control.layers(
#                 layer_control_c665de7a9c0e87dd4356bdf537cbc0ce_layers.base_layers,
#                 layer_control_c665de7a9c0e87dd4356bdf537cbc0ce_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_c8fa09b857645eef1360d05127a03f12);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Cloud Masking

# %% [markdown]
# ### Pathrow 124062 (Prefire)

# %%
import ee
import folium
import geemap.foliumap as geemap

#Fungsi agar folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


#Pathrow dan rentang waktu data
path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-01-01'
end_date = '2023-07-31'

#Ambil koleksi citra LANDSAT 9 TOA berdasarkan Pathrow dan rentang waktu
collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER')

#Pilih citra dengan cloud cover terendah
image_best = collection.first() #Mengambil citra pertama dari Collection berdasarkan pathrow, rentang waktu dan cloudcover
roi_geometry = image_best.geometry() #ROI geometri berdasarkan image_best, membantu DOS hanya spesifik di ROI

#DARK OBJECT SUBTRACTION (DOS)
def dos(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=roi_geometry,
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

#Terapkan DOS pada setiap citra
def apply_dos(img):
    dos_img = dos(img, ['B7', 'B5', 'B4'])
    return dos_img.copyProperties(img, img.propertyNames())

#Koleksi hasil koreksi atmosferik (DOS)
dos_collection = collection.map(apply_dos)
composite_before = dos_collection.median()


# Fungsi Cloud Masking menggunakan QA_PIXEL dari citra asli
def cloudmask(dos_img): #FUngsi cloudmask memanggil dos_img dari fungsi apply_dos
    system_index = dos_img.get('system:index')  # Mengambil ID sistem citra input (yang sudah dikoreksi DOS)
    original = collection.filter(ee.Filter.eq('system:index', system_index)).first() # Mengambil citra asli dari koleksi berdasarkan system:index yang sama
    qa = original.select('QA_PIXEL') # Menyeleksi band QA_PIXEL dari citra asli

    #Bit untuk masking kualitas citra dari QA_PIXEL
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    clear   = (1 << 6)  # Bit 6: Clear

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(clear).neq(0))
    return dos_img.updateMask(mask)

#Terapkan masking awan ke citra hasil DOS
masked_dos_collection = dos_collection.map(cloudmask)

#Composite setelah masking (akan ada lubang karena masking)
composite_after = masked_dos_collection.median()

#Tambal lubang dengan composite sebelum masking
dos_corrected = composite_after.unmask(composite_before)


#visualisasi
false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'Cloud Masking (QA Bands)')
m.add_child(folium.LayerControl())

title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Cloud Masking | Pathrow 124062 | Prefire
     </b></h3>
'''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ee5fc1b119f7c7c0a5669c1300a7774 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Cloud Masking | Pathrow 124062 | Prefire
#      &lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ee5fc1b119f7c7c0a5669c1300a7774&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ee5fc1b119f7c7c0a5669c1300a7774 = L.map(
#                 &quot;map_5ee5fc1b119f7c7c0a5669c1300a7774&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4227dac405c69989b1b76db4993d40ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4227dac405c69989b1b76db4993d40ae.addTo(map_5ee5fc1b119f7c7c0a5669c1300a7774);
#
#
#             var tile_layer_8b5d0c719dcb50a4b179ffd2294d93d1 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/b7a9e9fba1ac8fec05d07adb6d903101-6630a365728301800b4b95ab4c53a070/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8b5d0c719dcb50a4b179ffd2294d93d1.addTo(map_5ee5fc1b119f7c7c0a5669c1300a7774);
#
#
#             var layer_control_b5be18e89f927d5aee03106256f23497_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_4227dac405c69989b1b76db4993d40ae,
#                 },
#                 overlays :  {
#                     &quot;Cloud Masking (QA Bands)&quot; : tile_layer_8b5d0c719dcb50a4b179ffd2294d93d1,
#                 },
#             };
#             let layer_control_b5be18e89f927d5aee03106256f23497 = L.control.layers(
#                 layer_control_b5be18e89f927d5aee03106256f23497_layers.base_layers,
#                 layer_control_b5be18e89f927d5aee03106256f23497_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_5ee5fc1b119f7c7c0a5669c1300a7774);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Pathrow 125062 (Prefire)

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-01-01'
end_date = '2023-07-31'


collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER')

image_best = collection.first()
roi_geometry = image_best.geometry()

def dos(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=roi_geometry,
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

def apply_dos(img):
    dos_img = dos(img, ['B7', 'B5', 'B4'])
    return dos_img.copyProperties(img, img.propertyNames())

dos_collection = collection.map(apply_dos)
composite_before = dos_collection.median()


def cloudmask(dos_img):
    system_index = dos_img.get('system:index')
    original = collection.filter(ee.Filter.eq('system:index', system_index)).first()
    qa = original.select('QA_PIXEL')
    #Bit untuk masking kualitas citra dari QA_PIXEL
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    clear   = (1 << 6)

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(clear).neq(0))
    return dos_img.updateMask(mask)

masked_dos_collection = dos_collection.map(cloudmask)
composite_after = masked_dos_collection.median()
dos_corrected = composite_after.unmask(composite_before)

false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'Cloud Masking (QA Bands)')
m.add_child(folium.LayerControl())

title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Cloud Masking | Pathrow 125062 | Prefire
     </b></h3>
'''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1c9a2fbd98598ed282c2fdd60f09abd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Cloud Masking | Pathrow 125062 | Prefire
#      &lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1c9a2fbd98598ed282c2fdd60f09abd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1c9a2fbd98598ed282c2fdd60f09abd = L.map(
#                 &quot;map_f1c9a2fbd98598ed282c2fdd60f09abd&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21201f0eba07d663fc755e6d3eda5c8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_21201f0eba07d663fc755e6d3eda5c8d.addTo(map_f1c9a2fbd98598ed282c2fdd60f09abd);
#
#
#             var tile_layer_4d9ee3c47fa6a40981e597a7c2a07bf1 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/fdcbfc5751f3037d173ca4859d280691-db8d930ae2ab1c0721b4fec0c65b277b/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d9ee3c47fa6a40981e597a7c2a07bf1.addTo(map_f1c9a2fbd98598ed282c2fdd60f09abd);
#
#
#             var layer_control_ef22e5e81fc1fd4b420cef969ae5e851_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_21201f0eba07d663fc755e6d3eda5c8d,
#                 },
#                 overlays :  {
#                     &quot;Cloud Masking (QA Bands)&quot; : tile_layer_4d9ee3c47fa6a40981e597a7c2a07bf1,
#                 },
#             };
#             let layer_control_ef22e5e81fc1fd4b420cef969ae5e851 = L.control.layers(
#                 layer_control_ef22e5e81fc1fd4b420cef969ae5e851_layers.base_layers,
#                 layer_control_ef22e5e81fc1fd4b420cef969ae5e851_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_f1c9a2fbd98598ed282c2fdd60f09abd);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Pathrow 124062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'


collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER')

image_best = collection.first()
roi_geometry = image_best.geometry()

def dos(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=roi_geometry,
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

def apply_dos(img):
    dos_img = dos(img, ['B7', 'B5', 'B4'])
    return dos_img.copyProperties(img, img.propertyNames())

dos_collection = collection.map(apply_dos)
composite_before = dos_collection.median()

def cloudmask(dos_img):
    system_index = dos_img.get('system:index')
    original = collection.filter(ee.Filter.eq('system:index', system_index)).first()
    qa = original.select('QA_PIXEL')
    #Bit untuk masking kualitas citra dari QA_PIXEL
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    clear   = (1 << 6)

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(clear).neq(0))
    return dos_img.updateMask(mask)



masked_dos_collection = dos_collection.map(cloudmask)
composite_after = masked_dos_collection.median()
dos_corrected = composite_after.unmask(composite_before)

false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'Cloud Masking (QA Bands)')
m.add_child(folium.LayerControl())

title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Cloud Masking | Pathrow 124062 | Postfire
     </b></h3>
'''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35ff54e99e844da965c373d07c4ae253 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Cloud Masking | Pathrow 124062 | Postfire
#      &lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35ff54e99e844da965c373d07c4ae253&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35ff54e99e844da965c373d07c4ae253 = L.map(
#                 &quot;map_35ff54e99e844da965c373d07c4ae253&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e37c0da3919cd1a2a55c1d3c80164ded = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e37c0da3919cd1a2a55c1d3c80164ded.addTo(map_35ff54e99e844da965c373d07c4ae253);
#
#
#             var tile_layer_448f4c7b91ce43d9be3d17b699a58252 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/821ebc1edb70fc7c9cb1294cd5246bae-0a61ad02d82832d753bf058df8adf9aa/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_448f4c7b91ce43d9be3d17b699a58252.addTo(map_35ff54e99e844da965c373d07c4ae253);
#
#
#             var layer_control_42fb9c4f5795cfb7bef6fd61988ea7a8_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_e37c0da3919cd1a2a55c1d3c80164ded,
#                 },
#                 overlays :  {
#                     &quot;Cloud Masking (QA Bands)&quot; : tile_layer_448f4c7b91ce43d9be3d17b699a58252,
#                 },
#             };
#             let layer_control_42fb9c4f5795cfb7bef6fd61988ea7a8 = L.control.layers(
#                 layer_control_42fb9c4f5795cfb7bef6fd61988ea7a8_layers.base_layers,
#                 layer_control_42fb9c4f5795cfb7bef6fd61988ea7a8_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_35ff54e99e844da965c373d07c4ae253);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Pathrow 125062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'


collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER')

image_best = collection.first()
roi_geometry = image_best.geometry()

def dos(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=roi_geometry,
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

def apply_dos(img):
    dos_img = dos(img, ['B7', 'B5', 'B4'])
    return dos_img.copyProperties(img, img.propertyNames())

dos_collection = collection.map(apply_dos)
composite_before = dos_collection.median()


def cloudmask(dos_img):
    system_index = dos_img.get('system:index')
    original = collection.filter(ee.Filter.eq('system:index', system_index)).first()
    qa = original.select('QA_PIXEL')
    #Bit untuk masking kualitas citra dari QA_PIXEL
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    clear   = (1 << 6)

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(clear).neq(0))
    return dos_img.updateMask(mask)

masked_dos_collection = dos_collection.map(cloudmask)
composite_after = masked_dos_collection.median()
dos_corrected = composite_after.unmask(composite_before)

false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'Cloud Masking (QA Bands)')
m.add_child(folium.LayerControl())

title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Cloud Masking | Pathrow 125062 | Postfire
     </b></h3>
'''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc52ef6960f2b206dbb6207a1c47ff57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Cloud Masking | Pathrow 125062 | Postfire
#      &lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc52ef6960f2b206dbb6207a1c47ff57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc52ef6960f2b206dbb6207a1c47ff57 = L.map(
#                 &quot;map_fc52ef6960f2b206dbb6207a1c47ff57&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d81dec4129aef38eaae9800637912ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2d81dec4129aef38eaae9800637912ab.addTo(map_fc52ef6960f2b206dbb6207a1c47ff57);
#
#
#             var tile_layer_8aacb1f05150316ef1c45540f1649a95 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/4014c4c04b0c90ac2b97d32badce2895-b4846b17e3f505704d0a9b54a2a6b0ab/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8aacb1f05150316ef1c45540f1649a95.addTo(map_fc52ef6960f2b206dbb6207a1c47ff57);
#
#
#             var layer_control_54b696ebf21e2ab507ede1d7dba1492e_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_2d81dec4129aef38eaae9800637912ab,
#                 },
#                 overlays :  {
#                     &quot;Cloud Masking (QA Bands)&quot; : tile_layer_8aacb1f05150316ef1c45540f1649a95,
#                 },
#             };
#             let layer_control_54b696ebf21e2ab507ede1d7dba1492e = L.control.layers(
#                 layer_control_54b696ebf21e2ab507ede1d7dba1492e_layers.base_layers,
#                 layer_control_54b696ebf21e2ab507ede1d7dba1492e_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_fc52ef6960f2b206dbb6207a1c47ff57);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Komposit Citra

# %% [markdown]
# ### False color 7-5-4 (Postfire) | 124

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'


collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER')

image_best = collection.first()
roi_geometry = image_best.geometry()

def dos(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=roi_geometry,
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

def apply_dos(img):
    dos_img = dos(img, ['B7', 'B5', 'B4'])
    return dos_img.copyProperties(img, img.propertyNames())

dos_collection = collection.map(apply_dos)
composite_before = dos_collection.median()


def cloudmask(dos_img):
    system_index = dos_img.get('system:index')
    original = collection.filter(ee.Filter.eq('system:index', system_index)).first()
    qa = original.select('QA_PIXEL')
    #Bit untuk masking kualitas citra dari QA_PIXEL
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    clear   = (1 << 6)

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(clear).neq(0))
    return dos_img.updateMask(mask)

masked_dos_collection = dos_collection.map(cloudmask)
composite_after = masked_dos_collection.median()
dos_corrected = composite_after.unmask(composite_before)

false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'Cloud Masking (QA Bands)')
m.add_child(folium.LayerControl())

title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     False Color | Pathrow 124062 | Postfire
     </b></h3>
'''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3263ebad33df8d936cfbd5a950b606b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      False Color | Pathrow 124062 | Postfire
#      &lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3263ebad33df8d936cfbd5a950b606b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3263ebad33df8d936cfbd5a950b606b0 = L.map(
#                 &quot;map_3263ebad33df8d936cfbd5a950b606b0&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cbc041ef42cc57b5d61777c6936551c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cbc041ef42cc57b5d61777c6936551c8.addTo(map_3263ebad33df8d936cfbd5a950b606b0);
#
#
#             var tile_layer_01d3c0b5d117a4266a1a93cc9325f1d3 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/821ebc1edb70fc7c9cb1294cd5246bae-0335d63a37897d98708e2f23da3160f2/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_01d3c0b5d117a4266a1a93cc9325f1d3.addTo(map_3263ebad33df8d936cfbd5a950b606b0);
#
#
#             var layer_control_0f72926c256766b9e1fdaa7b777b9276_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_cbc041ef42cc57b5d61777c6936551c8,
#                 },
#                 overlays :  {
#                     &quot;Cloud Masking (QA Bands)&quot; : tile_layer_01d3c0b5d117a4266a1a93cc9325f1d3,
#                 },
#             };
#             let layer_control_0f72926c256766b9e1fdaa7b777b9276 = L.control.layers(
#                 layer_control_0f72926c256766b9e1fdaa7b777b9276_layers.base_layers,
#                 layer_control_0f72926c256766b9e1fdaa7b777b9276_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_3263ebad33df8d936cfbd5a950b606b0);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### False Color 7-5-4 (Postfire) | 125

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'


collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER')

image_best = collection.first()
roi_geometry = image_best.geometry()

def dos(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=roi_geometry,
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

def apply_dos(img):
    dos_img = dos(img, ['B7', 'B5', 'B4'])
    return dos_img.copyProperties(img, img.propertyNames())

dos_collection = collection.map(apply_dos)
composite_before = dos_collection.median()


def cloudmask(dos_img):
    system_index = dos_img.get('system:index')
    original = collection.filter(ee.Filter.eq('system:index', system_index)).first()
    qa = original.select('QA_PIXEL')
    #Bit untuk masking kualitas citra dari QA_PIXEL
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    clear   = (1 << 6)

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(clear).neq(0))
    return dos_img.updateMask(mask)

masked_dos_collection = dos_collection.map(cloudmask)
composite_after = masked_dos_collection.median()
dos_corrected = composite_after.unmask(composite_before)

false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'Cloud Masking (QA Bands)')
m.add_child(folium.LayerControl())

title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     False Color | Pathrow 125062 | Postfire
     </b></h3>
'''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_857c90270f6de1dfdf2e4802b477245a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      False Color | Pathrow 125062 | Postfire
#      &lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_857c90270f6de1dfdf2e4802b477245a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_857c90270f6de1dfdf2e4802b477245a = L.map(
#                 &quot;map_857c90270f6de1dfdf2e4802b477245a&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3bbfe1ef0bf4ba0fcf63dea09261f12 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c3bbfe1ef0bf4ba0fcf63dea09261f12.addTo(map_857c90270f6de1dfdf2e4802b477245a);
#
#
#             var tile_layer_1ff6a2830c5082d49db09becf23bcd8a = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/4014c4c04b0c90ac2b97d32badce2895-063b3c770b57277e7312fb5d1015deeb/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ff6a2830c5082d49db09becf23bcd8a.addTo(map_857c90270f6de1dfdf2e4802b477245a);
#
#
#             var layer_control_73173bedce9a395907f4e86b543cb161_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_c3bbfe1ef0bf4ba0fcf63dea09261f12,
#                 },
#                 overlays :  {
#                     &quot;Cloud Masking (QA Bands)&quot; : tile_layer_1ff6a2830c5082d49db09becf23bcd8a,
#                 },
#             };
#             let layer_control_73173bedce9a395907f4e86b543cb161 = L.control.layers(
#                 layer_control_73173bedce9a395907f4e86b543cb161_layers.base_layers,
#                 layer_control_73173bedce9a395907f4e86b543cb161_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_857c90270f6de1dfdf2e4802b477245a);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Ekstraksi Fitur

# %% [markdown]
# ## NDVI Pathrow 124062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap

# Fungsi agar folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

#Filter lokasi dan waktu
path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'


# Fungsi DOS
def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)

#Fungsi Masking awan QA_PIXEL
def mask_fmask(image):
    qa = image.select('QA_PIXEL')

    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    clear   = (1 << 6)

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(clear).neq(0))
    return image.updateMask(mask)


# Ambil koleksi dan terapkan DOS
collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)

#Hitung NDVI dari citra mentah
ndvi_fill = collection.map(lambda img: img.normalizedDifference(['B5', 'B4']).rename('NDVI')).median()
# Masking awan
masked_collection = collection.map(mask_fmask)
# Hitung NDVI dari citra yang sudah di-mask
ndvi_masked = masked_collection.map(lambda img: img.normalizedDifference(['B5', 'B4']).rename('NDVI'))
ndvi_composite = ndvi_masked.median()

# Ambil geometri dari image pertama
first_image = collection.first()
geometry = first_image.geometry()

#Unmask bagian berlubang dan clip ke ROI
ndvi_filled = ndvi_composite.unmask(ndvi_fill).clip(geometry)


# Visualisasi NDVI
ndvi_vis_params = {
    'min': -1,
    'max': 1,
    'palette': ['red', 'orange', 'yellow', 'green', 'darkgreen']
}


# Tampilkan ke peta dengan FOLIUM
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(ndvi_filled, ndvi_vis_params, 'NDVI Pathrow 124062')

# Tambahkan Layer Control
m.add_child(folium.LayerControl())

# ========================================
# Tambahkan Legenda NDVI
legend_keys = [
    '< 0: Non Vegetasi',
    '0 - 0.2: Vegetasi Sangat Jarang',
    '0.2 - 0.4: Vegetasi Rendah',
    '0.4 - 0.6: Vegetasi Sedang-Lebat',
    '> 0.6: Vegetasi Sangat Lebat'
]

legend_colors = [
    (255, 0, 0),         # red
    (255, 165, 0),       # orange
    (255, 255, 0),       # yellow
    (0, 128, 0),         # green
    (0, 100, 0)          # darkgreen
]

legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>NDVI pathrow 124062</b><br>
'''

for label, color in zip(legend_keys, legend_colors):
    rgb = f'rgb{color}'
    legend_html += f'<i style="background:{rgb};width:12px;height:12px;display:inline-block;margin-right:6px;"></i>{label}<br>'

legend_html += '</div>'
m.get_root().html.add_child(folium.Element(legend_html))

# Tampilkan Peta
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# WARNING:googleapiclient.http:Sleeping 1.61 seconds before retry 1 of 5 for request: POST https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps?fields=name&alt=json, after 429
# WARNING:googleapiclient.http:Sleeping 3.98 seconds before retry 2 of 5 for request: POST https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps?fields=name&alt=json, after 429
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e11a5a0ab4fe540bf2ba8ba56970dd3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;NDVI pathrow 124062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(255, 0, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&lt; 0: Non Vegetasi&lt;br&gt;&lt;i style=&quot;background:rgb(255, 165, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0 - 0.2: Vegetasi Sangat Jarang&lt;br&gt;&lt;i style=&quot;background:rgb(255, 255, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.2 - 0.4: Vegetasi Rendah&lt;br&gt;&lt;i style=&quot;background:rgb(0, 128, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.4 - 0.6: Vegetasi Sedang-Lebat&lt;br&gt;&lt;i style=&quot;background:rgb(0, 100, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&gt; 0.6: Vegetasi Sangat Lebat&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e11a5a0ab4fe540bf2ba8ba56970dd3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e11a5a0ab4fe540bf2ba8ba56970dd3 = L.map(
#                 &quot;map_4e11a5a0ab4fe540bf2ba8ba56970dd3&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db91beedb4cf109d984de5aa90b61544 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db91beedb4cf109d984de5aa90b61544.addTo(map_4e11a5a0ab4fe540bf2ba8ba56970dd3);
#
#
#             var tile_layer_9ff601dbf557619d546fe3bb9dcca780 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/e9caf445b7f5c9ae20ca7a68e6a1ff19-650987c6eb13caf1631d3edc12f13b82/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9ff601dbf557619d546fe3bb9dcca780.addTo(map_4e11a5a0ab4fe540bf2ba8ba56970dd3);
#
#
#             var layer_control_f56e90bf0d6224c3d80ffe491fff4c21_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_db91beedb4cf109d984de5aa90b61544,
#                 },
#                 overlays :  {
#                     &quot;NDVI Pathrow 124062&quot; : tile_layer_9ff601dbf557619d546fe3bb9dcca780,
#                 },
#             };
#             let layer_control_f56e90bf0d6224c3d80ffe491fff4c21 = L.control.layers(
#                 layer_control_f56e90bf0d6224c3d80ffe491fff4c21_layers.base_layers,
#                 layer_control_f56e90bf0d6224c3d80ffe491fff4c21_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_4e11a5a0ab4fe540bf2ba8ba56970dd3);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## NDVI Pathrow 125062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'

def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)

def mask_fmask(image):
    qa = image.select('QA_PIXEL')
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    clear   = (1 << 6)

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(clear).neq(0))
    return image.updateMask(mask)


collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)

ndvi_fill = collection.map(lambda img: img.normalizedDifference(['B5', 'B4']).rename('NDVI')).median()
masked_collection = collection.map(mask_fmask)
ndvi_masked = masked_collection.map(lambda img: img.normalizedDifference(['B5', 'B4']).rename('NDVI'))
ndvi_composite = ndvi_masked.median()


first_image = collection.first()
geometry = first_image.geometry()
ndvi_filled = ndvi_composite.unmask(ndvi_fill).clip(geometry)


ndvi_vis_params = {
    'min': -1,
    'max': 1,
    'palette': ['red', 'orange', 'yellow', 'green', 'darkgreen']
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(ndvi_filled, ndvi_vis_params, 'NDVI Pathrow 124062')
m.add_child(folium.LayerControl())


legend_keys = [
    '< 0: Non Vegetasi',
    '0 - 0.2: Vegetasi Sangat Jarang',
    '0.2 - 0.4: Vegetasi Rendah',
    '0.4 - 0.6: Vegetasi Sedang-Lebat',
    '> 0.6: Vegetasi Sangat Lebat'
]
legend_colors = [
    (255, 0, 0),         # red
    (255, 165, 0),       # orange
    (255, 255, 0),       # yellow
    (0, 128, 0),         # green
    (0, 100, 0)          # darkgreen
]
legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>NDVI Pathrow 125062</b><br>
'''
for label, color in zip(legend_keys, legend_colors):
    rgb = f'rgb{color}'
    legend_html += f'<i style="background:{rgb};width:12px;height:12px;display:inline-block;margin-right:6px;"></i>{label}<br>'

legend_html += '</div>'
m.get_root().html.add_child(folium.Element(legend_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b15ed4166dd0b7d422f4639be087af87 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;NDVI Pathrow 125062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(255, 0, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&lt; 0: Non Vegetasi&lt;br&gt;&lt;i style=&quot;background:rgb(255, 165, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0 - 0.2: Vegetasi Sangat Jarang&lt;br&gt;&lt;i style=&quot;background:rgb(255, 255, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.2 - 0.4: Vegetasi Rendah&lt;br&gt;&lt;i style=&quot;background:rgb(0, 128, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.4 - 0.6: Vegetasi Sedang-Lebat&lt;br&gt;&lt;i style=&quot;background:rgb(0, 100, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&gt; 0.6: Vegetasi Sangat Lebat&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b15ed4166dd0b7d422f4639be087af87&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b15ed4166dd0b7d422f4639be087af87 = L.map(
#                 &quot;map_b15ed4166dd0b7d422f4639be087af87&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09eb8afc1a63b1314a240847d09064cc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09eb8afc1a63b1314a240847d09064cc.addTo(map_b15ed4166dd0b7d422f4639be087af87);
#
#
#             var tile_layer_ede041dbb36d5621f969a4237c0dac07 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/8a9a561b3c7411979a9374bc0ad80b44-587f20730b07d64e57b8790f998ed987/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ede041dbb36d5621f969a4237c0dac07.addTo(map_b15ed4166dd0b7d422f4639be087af87);
#
#
#             var layer_control_ec48995f07b1e4506b5d2024b86b691d_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_09eb8afc1a63b1314a240847d09064cc,
#                 },
#                 overlays :  {
#                     &quot;NDVI Pathrow 124062&quot; : tile_layer_ede041dbb36d5621f969a4237c0dac07,
#                 },
#             };
#             let layer_control_ec48995f07b1e4506b5d2024b86b691d = L.control.layers(
#                 layer_control_ec48995f07b1e4506b5d2024b86b691d_layers.base_layers,
#                 layer_control_ec48995f07b1e4506b5d2024b86b691d_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_b15ed4166dd0b7d422f4639be087af87);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## NBR Pathrow 124062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap

# Fungsi agar folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


# Filter lokasi dan waktu
path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'


# Fungsi koreksi atmosfer Dark Object Subtraction (DOS1)
def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)

# Fungsi masking awan berdasarkan QA_PIXEL
def mask_fmask(image):
    qa = image.select('QA_PIXEL')
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    clear   = (1 << 6)

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(clear).neq(0))

    return image.updateMask(mask)

# Ambil koleksi citra dan terapkan DOS
collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)

#Hitung NBR dari citra mentah untuk penambal lubang
nbr_fill = collection.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()

#Masking awan
masked_collection = collection.map(mask_fmask)

#Hitung NBR dari citra yang sudah di-mask
nbr_masked = masked_collection.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
nbr_composite = nbr_masked.median()

# Ambil geometri dari citra pertama
first_image = collection.first()
geometry = first_image.geometry()

# Unmask bagian berlubang dan clip ke ROI
nbr_filled = nbr_composite.unmask(nbr_fill).clip(geometry)


# Parameter visualisasi NBR
nbr_vis_params = {
    'min': -1,
    'max': 1,
    'palette': ['red', 'orange', 'yellow', 'green', 'darkgreen']
}

m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(nbr_filled, nbr_vis_params, 'NBR Pathrow 124062')
m.add_child(folium.LayerControl())

# Tambahkan Legenda NBR
legend_keys = [
    '< 0: Non Vegetasi',
    '0 - 0.2: Vegetasi Sangat Jarang',
    '0.2 - 0.4: Vegetasi Rendah',
    '0.4 - 0.6: Vegetasi Sedang-Lebat',
    '> 0.6: Vegetasi Sangat Lebat'
]

legend_colors = [
    (255, 0, 0),         # red
    (255, 165, 0),       # orange
    (255, 255, 0),       # yellow
    (0, 128, 0),         # green
    (0, 100, 0)          # darkgreen
]


legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>NBR Pathrow 124062</b><br>
'''

for label, color in zip(legend_keys, legend_colors):
    rgb = f'rgb{color}'
    legend_html += f'<i style="background:{rgb};width:12px;height:12px;display:inline-block;margin-right:6px;"></i>{label}<br>'

legend_html += '</div>'
m.get_root().html.add_child(folium.Element(legend_html))

m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_648ed6cf40d53dafa47f04b3e978199f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;NBR Pathrow 124062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(255, 0, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&lt; 0: Non Vegetasi&lt;br&gt;&lt;i style=&quot;background:rgb(255, 165, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0 - 0.2: Vegetasi Sangat Jarang&lt;br&gt;&lt;i style=&quot;background:rgb(255, 255, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.2 - 0.4: Vegetasi Rendah&lt;br&gt;&lt;i style=&quot;background:rgb(0, 128, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.4 - 0.6: Vegetasi Sedang-Lebat&lt;br&gt;&lt;i style=&quot;background:rgb(0, 100, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&gt; 0.6: Vegetasi Sangat Lebat&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_648ed6cf40d53dafa47f04b3e978199f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_648ed6cf40d53dafa47f04b3e978199f = L.map(
#                 &quot;map_648ed6cf40d53dafa47f04b3e978199f&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d90f9657d765eabf4bbf4f445fcb4a0c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d90f9657d765eabf4bbf4f445fcb4a0c.addTo(map_648ed6cf40d53dafa47f04b3e978199f);
#
#
#             var tile_layer_3cef8312a5144b564e2eb12bbbfed4f6 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/deba9a2be971a7999bcba427e85db20e-d4e59e318e9dc9909fdd323bdb56bd33/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3cef8312a5144b564e2eb12bbbfed4f6.addTo(map_648ed6cf40d53dafa47f04b3e978199f);
#
#
#             var layer_control_1971e196dec8530291b1500855cd64e1_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_d90f9657d765eabf4bbf4f445fcb4a0c,
#                 },
#                 overlays :  {
#                     &quot;NBR Pathrow 124062&quot; : tile_layer_3cef8312a5144b564e2eb12bbbfed4f6,
#                 },
#             };
#             let layer_control_1971e196dec8530291b1500855cd64e1 = L.control.layers(
#                 layer_control_1971e196dec8530291b1500855cd64e1_layers.base_layers,
#                 layer_control_1971e196dec8530291b1500855cd64e1_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_648ed6cf40d53dafa47f04b3e978199f);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## NBR Pathrow 125062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'

def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)


def mask_fmask(image):
    qa = image.select('QA_PIXEL')
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    clear   = (1 << 6)

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(clear).neq(0))
    return image.updateMask(mask)



collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)


nbr_fill = collection.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
masked_collection = collection.map(mask_fmask)
nbr_masked = masked_collection.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
nbr_composite = nbr_masked.median()


first_image = collection.first()
geometry = first_image.geometry()
nbr_filled = nbr_composite.unmask(nbr_fill).clip(geometry)


nbr_vis_params = {
    'min': -1,
    'max': 1,
    'palette': ['red', 'orange', 'yellow', 'green', 'darkgreen']
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(nbr_filled, nbr_vis_params, 'NBR Pathrow 124062')
m.add_child(folium.LayerControl())


legend_keys = [
    '< 0: Non Vegetasi',
    '0 - 0.2: Vegetasi Sangat Jarang',
    '0.2 - 0.4: Vegetasi Rendah',
    '0.4 - 0.6: Vegetasi Sedang-Lebat',
    '> 0.6: Vegetasi Sangat Lebat'
]
legend_colors = [
    (255, 0, 0),         # red
    (255, 165, 0),       # orange
    (255, 255, 0),       # yellow
    (0, 128, 0),         # green
    (0, 100, 0)          # darkgreen
]
legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>NBR Pathrow 125062</b><br>
'''

for label, color in zip(legend_keys, legend_colors):
    rgb = f'rgb{color}'
    legend_html += f'<i style="background:{rgb};width:12px;height:12px;display:inline-block;margin-right:6px;"></i>{label}<br>'
legend_html += '</div>'
m.get_root().html.add_child(folium.Element(legend_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_17972591f7a0614bb187aa6b4c0c1d40 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;NBR Pathrow 125062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(255, 0, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&lt; 0: Non Vegetasi&lt;br&gt;&lt;i style=&quot;background:rgb(255, 165, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0 - 0.2: Vegetasi Sangat Jarang&lt;br&gt;&lt;i style=&quot;background:rgb(255, 255, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.2 - 0.4: Vegetasi Rendah&lt;br&gt;&lt;i style=&quot;background:rgb(0, 128, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.4 - 0.6: Vegetasi Sedang-Lebat&lt;br&gt;&lt;i style=&quot;background:rgb(0, 100, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&gt; 0.6: Vegetasi Sangat Lebat&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_17972591f7a0614bb187aa6b4c0c1d40&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_17972591f7a0614bb187aa6b4c0c1d40 = L.map(
#                 &quot;map_17972591f7a0614bb187aa6b4c0c1d40&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6e10e269c8fc4d56b468a1b23913396 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a6e10e269c8fc4d56b468a1b23913396.addTo(map_17972591f7a0614bb187aa6b4c0c1d40);
#
#
#             var tile_layer_0592ce7cd612e8eafc01915e90255015 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/bd0a99a5d796a268d637493dbd06da7f-36129cb19fd79773ec25cf4cabd9ecb1/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0592ce7cd612e8eafc01915e90255015.addTo(map_17972591f7a0614bb187aa6b4c0c1d40);
#
#
#             var layer_control_72e0cc247a9df1948a18ca7b5371025f_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a6e10e269c8fc4d56b468a1b23913396,
#                 },
#                 overlays :  {
#                     &quot;NBR Pathrow 124062&quot; : tile_layer_0592ce7cd612e8eafc01915e90255015,
#                 },
#             };
#             let layer_control_72e0cc247a9df1948a18ca7b5371025f = L.control.layers(
#                 layer_control_72e0cc247a9df1948a18ca7b5371025f_layers.base_layers,
#                 layer_control_72e0cc247a9df1948a18ca7b5371025f_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_17972591f7a0614bb187aa6b4c0c1d40);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## DNBR

# %% [markdown]
# ### 124062

# %%
import ee
import folium
import geemap.foliumap as geemap


def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)


prefire_start = '2023-01-01'
prefire_end   = '2023-07-31'
postfire_start = '2023-11-01'
postfire_end   = '2023-12-31'



def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)



def mask_fmask(image):
    qa = image.select('QA_PIXEL')
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    clear   = (1 << 6)

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(clear).neq(0))
    return image.updateMask(mask)



prefire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(prefire_start, prefire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
prefire_fill = prefire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
prefire_masked = prefire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
prefire_nbr = prefire_masked.median().unmask(prefire_fill)


postfire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(postfire_start, postfire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
postfire_fill = postfire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
postfire_masked = postfire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
postfire_nbr = postfire_masked.median().unmask(postfire_fill)
dnbr = prefire_nbr.subtract(postfire_nbr).rename('dNBR')

dnbr_vis_params = {
    'min': -0.2,
    'max': 1,
    'palette': ['green', 'darkgreen', 'yellow', 'orange', 'red']
}

# =========================
# Peta
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dnbr, dnbr_vis_params, 'dNBR')
m.add_child(folium.LayerControl())

# =========================
# Legenda dNBR (4 kelas)
legend_keys = [
    '< 0.1: Tidak Terbakar',
    '0.1 - 0.27: Keparahan Rendah',
    '0.1 - 0.27: Keparahan Rendah-Sedang',
    '0.27 - 0.66: Keparahan Sedang-Tinggi',
    '> 0.66: Keparahan Tinggi'
]

legend_colors = [
    (0, 100, 0),       # green
    (0, 128, 0),       # darkgreen
    (255, 255, 0),     # yellow
    (255, 165, 0),     # orange
    (255, 0, 0),       # red
]

legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>dNBR Pathrow 124062</b><br>
'''

for label, color in zip(legend_keys, legend_colors):
    rgb = f'rgb{color}'
    legend_html += f'<i style="background:{rgb};width:12px;height:12px;display:inline-block;margin-right:6px;"></i>{label}<br>'

legend_html += '</div>'
m.get_root().html.add_child(folium.Element(legend_html))

# =========================
# Tampilkan
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# WARNING:googleapiclient.http:Sleeping 1.15 seconds before retry 1 of 5 for request: POST https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps?fields=name&alt=json, after 429
# WARNING:googleapiclient.http:Sleeping 3.06 seconds before retry 2 of 5 for request: POST https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps?fields=name&alt=json, after 429
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31e29354bc3ecf0a95cfbfefd50b6b64 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;dNBR Pathrow 124062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(0, 100, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&lt; 0.1: Tidak Terbakar&lt;br&gt;&lt;i style=&quot;background:rgb(0, 128, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.1 - 0.27: Keparahan Rendah&lt;br&gt;&lt;i style=&quot;background:rgb(255, 255, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.1 - 0.27: Keparahan Rendah-Sedang&lt;br&gt;&lt;i style=&quot;background:rgb(255, 165, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.27 - 0.66: Keparahan Sedang-Tinggi&lt;br&gt;&lt;i style=&quot;background:rgb(255, 0, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&gt; 0.66: Keparahan Tinggi&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31e29354bc3ecf0a95cfbfefd50b6b64&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31e29354bc3ecf0a95cfbfefd50b6b64 = L.map(
#                 &quot;map_31e29354bc3ecf0a95cfbfefd50b6b64&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c048a8850a021b74ed17da2a6b0cc223 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c048a8850a021b74ed17da2a6b0cc223.addTo(map_31e29354bc3ecf0a95cfbfefd50b6b64);
#
#
#             var tile_layer_3814602d34e7e8e9aca1df2adc5fad03 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/5fd7b7de12fb22f5fde15fb87b8de469-3ca4a1dc9b880a122ac73f03ce66a08f/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3814602d34e7e8e9aca1df2adc5fad03.addTo(map_31e29354bc3ecf0a95cfbfefd50b6b64);
#
#
#             var layer_control_b2983c07ad79af7df17d3a817976a2a5_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_c048a8850a021b74ed17da2a6b0cc223,
#                 },
#                 overlays :  {
#                     &quot;dNBR&quot; : tile_layer_3814602d34e7e8e9aca1df2adc5fad03,
#                 },
#             };
#             let layer_control_b2983c07ad79af7df17d3a817976a2a5 = L.control.layers(
#                 layer_control_b2983c07ad79af7df17d3a817976a2a5_layers.base_layers,
#                 layer_control_b2983c07ad79af7df17d3a817976a2a5_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_31e29354bc3ecf0a95cfbfefd50b6b64);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 125062

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

# Prefire dan postfire
prefire_start = '2023-01-01'
prefire_end   = '2023-07-31'
postfire_start = '2023-11-01'
postfire_end   = '2023-12-31'

#Dark Object Subtraction (DOS1)
def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)

# Fungsi masking awan
def mask_fmask(image):
    qa = image.select('QA_PIXEL')
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    clear   = (1 << 6)

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(clear).neq(0))
    return image.updateMask(mask)

# Ambil koleksi prefire
prefire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(prefire_start, prefire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
prefire_fill = prefire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
prefire_masked = prefire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
prefire_nbr = prefire_masked.median().unmask(prefire_fill)

#Ambil koleksi postfire
postfire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(postfire_start, postfire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
postfire_fill = postfire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
postfire_masked = postfire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
postfire_nbr = postfire_masked.median().unmask(postfire_fill)

#Hitung dNBR
dnbr = prefire_nbr.subtract(postfire_nbr).rename('dNBR')


# Visualisasi dNBR
dnbr_vis_params = {
    'min': -0.2,
    'max': 1,
    'palette': ['green', 'darkgreen', 'yellow', 'orange', 'red']
}


m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dnbr, dnbr_vis_params, 'dNBR')
m.add_child(folium.LayerControl())
legend_keys = [
    '< 0.1: Tidak Terbakar',
    '0.1 - 0.27: Keparahan Rendah',
    '0.1 - 0.27: Keparahan Rendah-Sedang',
    '0.27 - 0.66: Keparahan Sedang-Tinggi',
    '> 0.66: Keparahan Tinggi'
]

legend_colors = [
    (0, 100, 0),       # darkgreen
    (0, 128, 0),       # darkgreen
    (255, 255, 0),     # yellow
    (255, 165, 0),     # orange
    (255, 0, 0),       # red
]

legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>dNBR Pathrow 125062</b><br>
'''

for label, color in zip(legend_keys, legend_colors):
    rgb = f'rgb{color}'
    legend_html += f'<i style="background:{rgb};width:12px;height:12px;display:inline-block;margin-right:6px;"></i>{label}<br>'

legend_html += '</div>'
m.get_root().html.add_child(folium.Element(legend_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed3567db8971707719eee2370e642fd7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;dNBR Pathrow 125062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(0, 100, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&lt; 0.1: Tidak Terbakar&lt;br&gt;&lt;i style=&quot;background:rgb(0, 128, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.1 - 0.27: Keparahan Rendah&lt;br&gt;&lt;i style=&quot;background:rgb(255, 255, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.1 - 0.27: Keparahan Rendah-Sedang&lt;br&gt;&lt;i style=&quot;background:rgb(255, 165, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.27 - 0.66: Keparahan Sedang-Tinggi&lt;br&gt;&lt;i style=&quot;background:rgb(255, 0, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&gt; 0.66: Keparahan Tinggi&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed3567db8971707719eee2370e642fd7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed3567db8971707719eee2370e642fd7 = L.map(
#                 &quot;map_ed3567db8971707719eee2370e642fd7&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3d33d2489bc6cbf60ed5fa81cb1c0e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3d33d2489bc6cbf60ed5fa81cb1c0e8.addTo(map_ed3567db8971707719eee2370e642fd7);
#
#
#             var tile_layer_f700c42d0bd4f403d943a3baa344cfa6 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/c5caa7756c89f94f7e99ab808e5fbdb2-9510342e22789f4dd39a4ec0e564b441/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f700c42d0bd4f403d943a3baa344cfa6.addTo(map_ed3567db8971707719eee2370e642fd7);
#
#
#             var layer_control_03e9308c4f9e0d1f67531d9b80df736b_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_f3d33d2489bc6cbf60ed5fa81cb1c0e8,
#                 },
#                 overlays :  {
#                     &quot;dNBR&quot; : tile_layer_f700c42d0bd4f403d943a3baa344cfa6,
#                 },
#             };
#             let layer_control_03e9308c4f9e0d1f67531d9b80df736b = L.control.layers(
#                 layer_control_03e9308c4f9e0d1f67531d9b80df736b_layers.base_layers,
#                 layer_control_03e9308c4f9e0d1f67531d9b80df736b_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_ed3567db8971707719eee2370e642fd7);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Masking Citra

# %% [markdown]
# ### 124062

# %%
import ee
import folium
import geemap.foliumap as geemap


def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

# Prefire dan postfire
prefire_start = '2023-01-01'
prefire_end   = '2023-07-31'
postfire_start = '2023-11-01'
postfire_end   = '2023-12-31'

def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)


def mask_fmask(image):
    qa = image.select('QA_PIXEL')
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    clear   = (1 << 6)

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(clear).neq(0))
    return image.updateMask(mask)


prefire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(prefire_start, prefire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
prefire_fill = prefire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
prefire_masked = prefire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
prefire_nbr = prefire_masked.median().unmask(prefire_fill)


postfire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(postfire_start, postfire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
postfire_fill = postfire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
postfire_masked = postfire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
postfire_nbr = postfire_masked.median().unmask(postfire_fill)

#Hitung dNBR
dnbr = prefire_nbr.subtract(postfire_nbr).rename('dNBR')

#Thresholding: dNBR > 0.1
dnbr_mask = dnbr.gt(0.1).rename('BurnedMask').uint8()


# Visualisasi
mask_vis_params = {
    'min': 0,
    'max': 1,
    'palette': ['000000', 'ffffff']
}

m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dnbr_mask, mask_vis_params, 'Burned Area Mask (dNBR > 0.1)')
m.add_child(folium.LayerControl())
legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>Citra Mask 124062</b><br>
<i style="background:rgb(255,255,255);width:12px;height:12px;display:inline-block;margin-right:6px;"></i>Terbakar<br>
<i style="background:rgb(0,0,0);width:12px;height:12px;display:inline-block;margin-right:6px;"></i>Tidak Terbakar<br>
</div>
'''
m.get_root().html.add_child(folium.Element(legend_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dde3c1ac9a7826a30f694637576b4332 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;Citra Mask 124062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(255,255,255);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;Terbakar&lt;br&gt;
# &lt;i style=&quot;background:rgb(0,0,0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;Tidak Terbakar&lt;br&gt;
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dde3c1ac9a7826a30f694637576b4332&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dde3c1ac9a7826a30f694637576b4332 = L.map(
#                 &quot;map_dde3c1ac9a7826a30f694637576b4332&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b34cfcd6cd49fecd796d6c1a979b090a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b34cfcd6cd49fecd796d6c1a979b090a.addTo(map_dde3c1ac9a7826a30f694637576b4332);
#
#
#             var tile_layer_f80c383869ed91041f6e9f5b9576a74b = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/2f2ef042aa3408d8e8c65e597c43a740-09cb291e50e2a37cf005d4c6ebcb535e/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f80c383869ed91041f6e9f5b9576a74b.addTo(map_dde3c1ac9a7826a30f694637576b4332);
#
#
#             var layer_control_d67c778113be30e0a4e31ea571f0bd3d_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_b34cfcd6cd49fecd796d6c1a979b090a,
#                 },
#                 overlays :  {
#                     &quot;Burned Area Mask (dNBR \u003e 0.1)&quot; : tile_layer_f80c383869ed91041f6e9f5b9576a74b,
#                 },
#             };
#             let layer_control_d67c778113be30e0a4e31ea571f0bd3d = L.control.layers(
#                 layer_control_d67c778113be30e0a4e31ea571f0bd3d_layers.base_layers,
#                 layer_control_d67c778113be30e0a4e31ea571f0bd3d_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_dde3c1ac9a7826a30f694637576b4332);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 125062

# %%
import ee
import folium
import geemap.foliumap as geemap


def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

prefire_start = '2023-01-01'
prefire_end   = '2023-07-31'
postfire_start = '2023-11-01'
postfire_end   = '2023-12-31'

def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)


def mask_fmask(image):
    qa = image.select('QA_PIXEL')
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    clear   = (1 << 6)

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(clear).neq(0))
    return image.updateMask(mask)


prefire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(prefire_start, prefire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
prefire_fill = prefire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
prefire_masked = prefire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
prefire_nbr = prefire_masked.median().unmask(prefire_fill)


postfire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(postfire_start, postfire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
postfire_fill = postfire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
postfire_masked = postfire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
postfire_nbr = postfire_masked.median().unmask(postfire_fill)


dnbr = prefire_nbr.subtract(postfire_nbr).rename('dNBR')

dnbr_mask = dnbr.gt(0.1).rename('BurnedMask').uint8()


mask_vis_params = {
    'min': 0,
    'max': 1,
    'palette': ['000000', 'ffffff']
}

m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dnbr_mask, mask_vis_params, 'Burned Area Mask (dNBR > 0.1)')
m.add_child(folium.LayerControl())

legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>Citra Mask 125062</b><br>
<i style="background:rgb(255,255,255);width:12px;height:12px;display:inline-block;margin-right:6px;"></i>Terbakar<br>
<i style="background:rgb(0,0,0);width:12px;height:12px;display:inline-block;margin-right:6px;"></i>Tidak Terbakar<br>
</div>
'''
m.get_root().html.add_child(folium.Element(legend_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# WARNING:googleapiclient.http:Sleeping 0.23 seconds before retry 1 of 5 for request: POST https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps?fields=name&alt=json, after 429
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aec7a3c22ed08139249662f6563a05db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;Citra Mask 125062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(255,255,255);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;Terbakar&lt;br&gt;
# &lt;i style=&quot;background:rgb(0,0,0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;Tidak Terbakar&lt;br&gt;
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aec7a3c22ed08139249662f6563a05db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aec7a3c22ed08139249662f6563a05db = L.map(
#                 &quot;map_aec7a3c22ed08139249662f6563a05db&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74538e0aa7bf8d8995d9d5649c55479a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_74538e0aa7bf8d8995d9d5649c55479a.addTo(map_aec7a3c22ed08139249662f6563a05db);
#
#
#             var tile_layer_84383f7492f927bd4ac16e71d686df45 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/c100639428de04badaefc8afcf5285cf-0c5e7dcad30111fd72f055d8a2253ce2/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84383f7492f927bd4ac16e71d686df45.addTo(map_aec7a3c22ed08139249662f6563a05db);
#
#
#             var layer_control_5a71a53a06d8d68f4f5c6a4fab1416ed_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_74538e0aa7bf8d8995d9d5649c55479a,
#                 },
#                 overlays :  {
#                     &quot;Burned Area Mask (dNBR \u003e 0.1)&quot; : tile_layer_84383f7492f927bd4ac16e71d686df45,
#                 },
#             };
#             let layer_control_5a71a53a06d8d68f4f5c6a4fab1416ed = L.control.layers(
#                 layer_control_5a71a53a06d8d68f4f5c6a4fab1416ed_layers.base_layers,
#                 layer_control_5a71a53a06d8d68f4f5c6a4fab1416ed_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_aec7a3c22ed08139249662f6563a05db);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
