# %% [markdown]
# #Pemrograman Tugas Akhir:
#
#
# "Segmentasi Burned Area menggunakan Model U-Net pada Citra Landsat 9 (Studi Kasus: Sumatera Selatan)"
#
#
# *   Data Preprocessing
#     * Koreksi Atmosferik (Dark Object Substraction)
#     * Cloud Masking (QA Bands)
#     * Komposit Citra (False Color)
# *   Ekstraksi Fitur
#     * NDVI
#     * NBR
#     * dNBR
# *   Band Stacking
# *   Masking Citra
#
#
#
# Tools & Platform
#
# ![Google Earth Engine](https://img.shields.io/badge/-GEE-34A853?style=flat&logo=google-earth&logoColor=white)  ![Pandas](https://img.shields.io/badge/-Pandas-150458?style=flat&logo=pandas&logoColor=white)  ![Folium](https://img.shields.io/badge/-Folium-77B829?style=flat&logo=leaflet&logoColor=white)  ![geemap](https://img.shields.io/badge/-geemap-34A853?style=flat&logo=googleearth&logoColor=white)

# %% [markdown]
# # Inisialisasi dan Authentikasi GEE

# %%
import ee
ee.Authenticate() #Authentikasi GEE
ee.Initialize(project='ee-analafeanalber9') #Inisialisasi GEE dengan ID Project GEE

# %% [markdown]
# # Data Description (Data Raw)

# %% [markdown]
# ## Prefire (01-01-2023 until 31-07-2023)

# %%
import ee
import pandas as pd

#Inisiasi Pathrow dan rentang waktu data digunakan
path = 124
row = 62
start_date = '2023-01-01'
end_date = '2023-07-31'

#Memanggil Koleksi Citra berdasarkan pathrow dan rentang waktu data
landsat9_col = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(ee.Filter.eq('WRS_PATH', path)) \
    .filter(ee.Filter.eq('WRS_ROW', row)) \
    .filterDate(start_date, end_date)

#Memberikan informasi tanggal citra tersedia, persentas cloud cover serta id citra
dates = landsat9_col.aggregate_array('DATE_ACQUIRED').getInfo()
clouds = landsat9_col.aggregate_array('CLOUD_COVER').getInfo()
ids = landsat9_col.aggregate_array('LANDSAT_PRODUCT_ID').getInfo()


#Fungsi membuat dataframe
if dates:
    df = pd.DataFrame({
        'Pathrow': 124062,
        'Kondisi': 'Prefire',
        'Tanggal Citra': dates,
        'Cloud Cover (%)': clouds,
        'Product ID': ids
    })
    df
else:
    print("Tidak ada citra tersedia pada rentang waktu dan path/row tersebut.")

#Menampilkan dataframe sort berdasarkan cloud cover persentase terkecil ke terbesar
df = df.sort_values(by='Cloud Cover (%)', ascending=True).reset_index(drop=True)
df
# Out:
#     Pathrow  Kondisi Tanggal Citra  Cloud Cover (%)  \
# 0    124062  Prefire    2023-07-26            14.07
# 1    124062  Prefire    2023-04-21            29.16
# 2    124062  Prefire    2023-06-24            33.04
# 3    124062  Prefire    2023-03-20            54.76
# 4    124062  Prefire    2023-04-05            56.74
# 5    124062  Prefire    2023-05-23            57.75
# 6    124062  Prefire    2023-07-10            83.95
# 7    124062  Prefire    2023-01-15            84.48
# 8    124062  Prefire    2023-02-16            86.69
# 9    124062  Prefire    2023-06-08            93.87
# 10   124062  Prefire    2023-05-07           100.00
# 11   124062  Prefire    2023-03-04           100.00
#
#                                   Product ID
# 0   LC09_L1TP_124062_20230726_20230726_02_T1
# 1   LC09_L1TP_124062_20230421_20230421_02_T1
# 2   LC09_L1TP_124062_20230624_20230624_02_T1
# 3   LC09_L1TP_124062_20230320_20230320_02_T1
# 4   LC09_L1TP_124062_20230405_20230405_02_T1
# 5   LC09_L1TP_124062_20230523_20230523_02_T1
# 6   LC09_L1TP_124062_20230710_20230710_02_T1
# 7   LC09_L1TP_124062_20230115_20230313_02_T1
# 8   LC09_L1TP_124062_20230216_20230310_02_T1
# 9   LC09_L1TP_124062_20230608_20230608_02_T1
# 10  LC09_L1TP_124062_20230507_20230507_02_T1
# 11  LC09_L1TP_124062_20230304_20230307_02_T1

# %%
import ee
import folium
import geemap.foliumap as geemap

#Fungsi folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

# Filter Path/Row dan Tanggal
path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-01-01'
end_date = '2023-07-31'

#Akses koleksi citra
landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()

#metadata tanggal dan cloud cover
date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')

#Visualisasi Band
band5_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band7_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band4_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'red', 'darkred']
}


#Peta Interaktif
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(landsat9_toa.select('B7'), band7_vis_params, 'Band 7 (SWIR)')
m.add_ee_layer(landsat9_toa.select('B5'), band5_vis_params, 'Band 5 (NIR)')
m.add_ee_layer(landsat9_toa.select('B4'), band4_vis_params, 'Band 4 (RED)')

#Kontrol layer
m.add_child(folium.LayerControl())

#Tambahkan info di atas peta
title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Pathrow 124062 (Prefire)
     </b></h3>
     <h3 align="center" style="font-size:16px"><b>
     Tanggal Citra: {date_acquired} | Cloud Cover: {cloud_cover}%
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
# Citra yang ditampilkan diambil pada tanggal: 2023-07-26
# Persentase Cloud Cover: 14.07%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8db265a760c5ca997b68641f2a44c0dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Pathrow 124062 (Prefire)
#      &lt;/b&gt;&lt;/h3&gt;
#      &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;
#      Tanggal Citra: 2023-07-26 | Cloud Cover: 14.07%
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8db265a760c5ca997b68641f2a44c0dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8db265a760c5ca997b68641f2a44c0dd = L.map(
#                 &quot;map_8db265a760c5ca997b68641f2a44c0dd&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e39d96015f7ec8a979fc419b5aa643d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e39d96015f7ec8a979fc419b5aa643d5.addTo(map_8db265a760c5ca997b68641f2a44c0dd);
#
#
#             var tile_layer_607152a8f4caf606fa04e6edf080bf3d = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/fe882ac3406203b4a2ba3b3d93d1ae41-8bafb049de1763950f804d320621ecaa/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_607152a8f4caf606fa04e6edf080bf3d.addTo(map_8db265a760c5ca997b68641f2a44c0dd);
#
#
#             var tile_layer_f748106af239ebeb16cc71b6bfe6b586 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/7794988f6cdd0c3b66e037f092a55a87-d2b832f380d8064a8f115f15773e2037/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f748106af239ebeb16cc71b6bfe6b586.addTo(map_8db265a760c5ca997b68641f2a44c0dd);
#
#
#             var tile_layer_21eceae493911f26e57343e4015a5805 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/008c5b5a37c3bdcfe7848788c42aabba-b10ac666f5f8ea3ac02a74136ce93313/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_21eceae493911f26e57343e4015a5805.addTo(map_8db265a760c5ca997b68641f2a44c0dd);
#
#
#             var layer_control_48484c86c90b668c355f39ba3db45715_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_e39d96015f7ec8a979fc419b5aa643d5,
#                 },
#                 overlays :  {
#                     &quot;Band 7 (SWIR)&quot; : tile_layer_607152a8f4caf606fa04e6edf080bf3d,
#                     &quot;Band 5 (NIR)&quot; : tile_layer_f748106af239ebeb16cc71b6bfe6b586,
#                     &quot;Band 4 (RED)&quot; : tile_layer_21eceae493911f26e57343e4015a5805,
#                 },
#             };
#             let layer_control_48484c86c90b668c355f39ba3db45715 = L.control.layers(
#                 layer_control_48484c86c90b668c355f39ba3db45715_layers.base_layers,
#                 layer_control_48484c86c90b668c355f39ba3db45715_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_8db265a760c5ca997b68641f2a44c0dd);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import ee
import pandas as pd

path = 125
row = 62
start_date = '2023-01-01'
end_date = '2023-07-31'


landsat9_col = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(ee.Filter.eq('WRS_PATH', path)) \
    .filter(ee.Filter.eq('WRS_ROW', row)) \
    .filterDate(start_date, end_date)


dates = landsat9_col.aggregate_array('DATE_ACQUIRED').getInfo()
clouds = landsat9_col.aggregate_array('CLOUD_COVER').getInfo()
ids = landsat9_col.aggregate_array('LANDSAT_PRODUCT_ID').getInfo()


if dates:
    df = pd.DataFrame({
        'Pathrow': 125062,
        'Kondisi': 'Prefire',
        'Tanggal Citra': dates,
        'Cloud Cover (%)': clouds,
        'Product ID': ids
    })
    df
else:
    print("Tidak ada citra tersedia pada rentang waktu dan path/row tersebut.")

df = df.sort_values(by='Cloud Cover (%)', ascending=True).reset_index(drop=True)
df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     Pathrow  Kondisi Tanggal Citra  Cloud Cover (%)  \
# 0    125062  Prefire    2023-05-14            26.38
# 1    125062  Prefire    2023-01-22            50.78
# 2    125062  Prefire    2023-06-15            65.17
# 3    125062  Prefire    2023-04-12            66.80
# 4    125062  Prefire    2023-01-06            73.91
# 5    125062  Prefire    2023-04-28            75.61
# 6    125062  Prefire    2023-02-07            87.14
# 7    125062  Prefire    2023-07-01            90.50
# 8    125062  Prefire    2023-05-30            91.37
# 9    125062  Prefire    2023-03-27            92.76
# 10   125062  Prefire    2023-07-17            95.70
#
#                                   Product ID
# 0   LC09_L1TP_125062_20230514_20230514_02_T1
# 1   LC09_L1TP_125062_20230122_20230313_02_T1
# 2   LC09_L1TP_125062_20230615_20230615_02_T1
# 3   LC09_L1TP_125062_20230412_20230412_02_T1
# 4   LC09_L1TP_125062_20230106_20230314_02_T1
# 5   LC09_L1TP_125062_20230428_20230428_02_T1
# 6   LC09_L1TP_125062_20230207_20230310_02_T1
# 7   LC09_L1TP_125062_20230701_20230701_02_T1
# 8   LC09_L1TP_125062_20230530_20230530_02_T1
# 9   LC09_L1TP_125062_20230327_20230327_02_T1
# 10  LC09_L1TP_125062_20230717_20230717_02_T1

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

start_date = '2023-01-01'
end_date = '2023-07-31'

landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()

date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')

band5_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band7_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band4_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'red', 'darkred']
}


#Peta Interaktif
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(landsat9_toa.select('B7'), band7_vis_params, 'Band 7 (SWIR)')
m.add_ee_layer(landsat9_toa.select('B5'), band5_vis_params, 'Band 5 (NIR)')
m.add_ee_layer(landsat9_toa.select('B4'), band4_vis_params, 'Band 4 (RED)')
#Kontrol layer
m.add_child(folium.LayerControl())

#Tambahkan info di atas peta
title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Pathrow 125062 (Prefire)
     </b></h3>

     <h3 align="center" style="font-size:16px"><b>
     Tanggal Citra: {date_acquired} | Cloud Cover: {cloud_cover}%
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Citra yang ditampilkan diambil pada tanggal: 2023-05-14
# Persentase Cloud Cover: 26.38%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03b435af01bbd3b3145c74328d8ba287 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Pathrow 125062 (Prefire)
#      &lt;/b&gt;&lt;/h3&gt;
#
#      &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;
#      Tanggal Citra: 2023-05-14 | Cloud Cover: 26.38%
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03b435af01bbd3b3145c74328d8ba287&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03b435af01bbd3b3145c74328d8ba287 = L.map(
#                 &quot;map_03b435af01bbd3b3145c74328d8ba287&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e04216075f8bf0fe4690e8352d10401d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e04216075f8bf0fe4690e8352d10401d.addTo(map_03b435af01bbd3b3145c74328d8ba287);
#
#
#             var tile_layer_f61eec46afa2a4241f3302ddb02127db = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/a1c33910e6d0dbeee6bd61ed5310e4a7-74adb1c3db41e5c93add949ff74bf2b3/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f61eec46afa2a4241f3302ddb02127db.addTo(map_03b435af01bbd3b3145c74328d8ba287);
#
#
#             var tile_layer_607c1aeed8f7d8fa4399e7ad808ac764 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/eaead19de72d1fa68761071ccb7315ec-c3e19d21dd3f33e82b7153957fa280bf/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_607c1aeed8f7d8fa4399e7ad808ac764.addTo(map_03b435af01bbd3b3145c74328d8ba287);
#
#
#             var tile_layer_a1f2045b4526a95b21cff6de56eec004 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/ba5eeb43d8a45e17b814bae89169e48f-656ac5797d808239520221aaccf36c34/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a1f2045b4526a95b21cff6de56eec004.addTo(map_03b435af01bbd3b3145c74328d8ba287);
#
#
#             var layer_control_6018bf14b689ad1382fd97c1a98f676e_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_e04216075f8bf0fe4690e8352d10401d,
#                 },
#                 overlays :  {
#                     &quot;Band 7 (SWIR)&quot; : tile_layer_f61eec46afa2a4241f3302ddb02127db,
#                     &quot;Band 5 (NIR)&quot; : tile_layer_607c1aeed8f7d8fa4399e7ad808ac764,
#                     &quot;Band 4 (RED)&quot; : tile_layer_a1f2045b4526a95b21cff6de56eec004,
#                 },
#             };
#             let layer_control_6018bf14b689ad1382fd97c1a98f676e = L.control.layers(
#                 layer_control_6018bf14b689ad1382fd97c1a98f676e_layers.base_layers,
#                 layer_control_6018bf14b689ad1382fd97c1a98f676e_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_03b435af01bbd3b3145c74328d8ba287);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Postfire (01-11-2023 until 31-12-2023

# %%
import ee
import pandas as pd

path = 124
row = 62
start_date = '2023-11-01'
end_date = '2023-12-31'

landsat9_col = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(ee.Filter.eq('WRS_PATH', path)) \
    .filter(ee.Filter.eq('WRS_ROW', row)) \
    .filterDate(start_date, end_date)

dates = landsat9_col.aggregate_array('DATE_ACQUIRED').getInfo()
clouds = landsat9_col.aggregate_array('CLOUD_COVER').getInfo()
ids = landsat9_col.aggregate_array('LANDSAT_PRODUCT_ID').getInfo()

if dates:
    df = pd.DataFrame({
        'Pathrow': 124062,
        'Kondisi': 'Postfire',
        'Tanggal Citra': dates,
        'Cloud Cover (%)': clouds,
        'Product ID': ids
    })
    df
else:
    print("Tidak ada citra tersedia pada rentang waktu dan path/row tersebut.")

df = df.sort_values(by='Cloud Cover (%)', ascending=True).reset_index(drop=True)
df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    Pathrow   Kondisi Tanggal Citra  Cloud Cover (%)  \
# 0   124062  Postfire    2023-11-15            23.63
# 1   124062  Postfire    2023-12-17            69.01
#
#                                  Product ID
# 0  LC09_L1TP_124062_20231115_20231115_02_T1
# 1  LC09_L1TP_124062_20231217_20231217_02_T1

# %%
import ee
import folium
import geemap.foliumap as geemap


def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

start_date = '2023-11-01'
end_date = '2023-12-31'


landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()


date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')


band5_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band7_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band4_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'red', 'darkred']
}


m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(landsat9_toa.select('B7'), band7_vis_params, 'Band 7 (SWIR)')
m.add_ee_layer(landsat9_toa.select('B5'), band5_vis_params, 'Band 5 (NIR)')
m.add_ee_layer(landsat9_toa.select('B4'), band4_vis_params, 'Band 4 (RED)')
m.add_child(folium.LayerControl())

title_html = f'''
<h3 align="center" style="font-size:20px"><b>
     Pathrow 124062 (Postfire)
     </b></h3>
     <h3 align="center" style="font-size:16px"><b>
     Tanggal Citra: {date_acquired} | Cloud Cover: {cloud_cover}%
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Citra yang ditampilkan diambil pada tanggal: 2023-11-15
# Persentase Cloud Cover: 23.63%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd9f9456198951260bcd14676cd21105 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Pathrow 124062 (Postfire)
#      &lt;/b&gt;&lt;/h3&gt;
#      &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;
#      Tanggal Citra: 2023-11-15 | Cloud Cover: 23.63%
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd9f9456198951260bcd14676cd21105&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd9f9456198951260bcd14676cd21105 = L.map(
#                 &quot;map_fd9f9456198951260bcd14676cd21105&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00a48d2ae3dbcd5146d491de4cb23ba5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_00a48d2ae3dbcd5146d491de4cb23ba5.addTo(map_fd9f9456198951260bcd14676cd21105);
#
#
#             var tile_layer_43fa7c90e501aca5fbdb186dd4e643c1 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/a538b63021fd27efec4d13c1ba2ea6ae-5e1e1f42117ca073f98a404ba9787d0a/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_43fa7c90e501aca5fbdb186dd4e643c1.addTo(map_fd9f9456198951260bcd14676cd21105);
#
#
#             var tile_layer_3a4f5bb6b9ada384f48c3031df7c40d6 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/495efe185cd62571cdf2ca5d0a29ac64-4682d01dbc810ee7e1125dd327930792/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3a4f5bb6b9ada384f48c3031df7c40d6.addTo(map_fd9f9456198951260bcd14676cd21105);
#
#
#             var tile_layer_44ca2ae0cc49afbf5f59a2554f334171 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/4d28ec6f7710e5e8330b5856c825233a-2b9c29f3dd945db08713b54a2a7a3712/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_44ca2ae0cc49afbf5f59a2554f334171.addTo(map_fd9f9456198951260bcd14676cd21105);
#
#
#             var layer_control_f6c4c0112b7acd33a998355682e4bc7b_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_00a48d2ae3dbcd5146d491de4cb23ba5,
#                 },
#                 overlays :  {
#                     &quot;Band 7 (SWIR)&quot; : tile_layer_43fa7c90e501aca5fbdb186dd4e643c1,
#                     &quot;Band 5 (NIR)&quot; : tile_layer_3a4f5bb6b9ada384f48c3031df7c40d6,
#                     &quot;Band 4 (RED)&quot; : tile_layer_44ca2ae0cc49afbf5f59a2554f334171,
#                 },
#             };
#             let layer_control_f6c4c0112b7acd33a998355682e4bc7b = L.control.layers(
#                 layer_control_f6c4c0112b7acd33a998355682e4bc7b_layers.base_layers,
#                 layer_control_f6c4c0112b7acd33a998355682e4bc7b_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_fd9f9456198951260bcd14676cd21105);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import ee
import pandas as pd

path = 125
row = 62
start_date = '2023-11-01'
end_date = '2023-12-31'

landsat9_col = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(ee.Filter.eq('WRS_PATH', path)) \
    .filter(ee.Filter.eq('WRS_ROW', row)) \
    .filterDate(start_date, end_date)

dates = landsat9_col.aggregate_array('DATE_ACQUIRED').getInfo()
clouds = landsat9_col.aggregate_array('CLOUD_COVER').getInfo()
ids = landsat9_col.aggregate_array('LANDSAT_PRODUCT_ID').getInfo()

# Buat DataFrame
if dates:
    df = pd.DataFrame({
        'Pathrow': 125062,
        'Kondisi': 'Postfire',
        'Tanggal Citra': dates,
        'Cloud Cover (%)': clouds,
        'Product ID': ids
    })
    df
else:
    print("Tidak ada citra tersedia pada rentang waktu dan path/row tersebut.")

df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#    Pathrow   Kondisi Tanggal Citra  Cloud Cover (%)  \
# 0   125062  Postfire    2023-11-06            41.67
# 1   125062  Postfire    2023-11-22            92.79
# 2   125062  Postfire    2023-12-08            69.28
# 3   125062  Postfire    2023-12-24           100.00
#
#                                  Product ID
# 0  LC09_L1TP_125062_20231106_20231106_02_T1
# 1  LC09_L1TP_125062_20231122_20231122_02_T1
# 2  LC09_L1TP_125062_20231208_20231208_02_T1
# 3  LC09_L1TP_125062_20231224_20231224_02_T1

# %%
import ee
import folium
import geemap.foliumap as geemap


def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

start_date = '2023-11-01'
end_date = '2023-12-31'

landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()

date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')

band5_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band7_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'white']
}
band4_vis_params = {
    'min': 0.0,
    'max': 0.5,
    'palette': ['black', 'red', 'darkred']
}



m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(landsat9_toa.select('B7'), band7_vis_params, 'Band 7 (SWIR)')
m.add_ee_layer(landsat9_toa.select('B5'), band5_vis_params, 'Band 5 (NIR)')
m.add_ee_layer(landsat9_toa.select('B4'), band4_vis_params, 'Band 4 (RED)')
m.add_child(folium.LayerControl())

title_html = f'''
  <h3 align="center" style="font-size:20px"><b>
     Pathrow 125062 (Postfire)
     </b></h3>
     <h3 align="center" style="font-size:16px"><b>
     Tanggal Citra: {date_acquired} | Cloud Cover: {cloud_cover}%
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Citra yang ditampilkan diambil pada tanggal: 2023-11-06
# Persentase Cloud Cover: 41.67%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_777478167064ce8e31e446db7a9aebaa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#   &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Pathrow 125062 (Postfire)
#      &lt;/b&gt;&lt;/h3&gt;
#      &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;
#      Tanggal Citra: 2023-11-06 | Cloud Cover: 41.67%
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_777478167064ce8e31e446db7a9aebaa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_777478167064ce8e31e446db7a9aebaa = L.map(
#                 &quot;map_777478167064ce8e31e446db7a9aebaa&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bed969a22512e5a565cfbc0e6b4c8c30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bed969a22512e5a565cfbc0e6b4c8c30.addTo(map_777478167064ce8e31e446db7a9aebaa);
#
#
#             var tile_layer_4769afa1d6a0896f3a29ad5938ff3bd6 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/f15ee64d59e296f6b7eac83bef1aa84f-f114deeef492f9c521990272ad2b3ace/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4769afa1d6a0896f3a29ad5938ff3bd6.addTo(map_777478167064ce8e31e446db7a9aebaa);
#
#
#             var tile_layer_3e6db492f7c3b6fad3e8b6538720b63e = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/3b80c832dc6b503ac786ec3fab257e6e-e9a815bd640ca85d0c56af2c314b65b6/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e6db492f7c3b6fad3e8b6538720b63e.addTo(map_777478167064ce8e31e446db7a9aebaa);
#
#
#             var tile_layer_0a1e417474758fa7e48dfee30a9d5637 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/b8d244980504ad7b01a7d0ab1204c114-53af540be53710b411da04a2c5a0b5cc/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a1e417474758fa7e48dfee30a9d5637.addTo(map_777478167064ce8e31e446db7a9aebaa);
#
#
#             var layer_control_5e25bd2ee3a48c3bb66a6728429a6646_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_bed969a22512e5a565cfbc0e6b4c8c30,
#                 },
#                 overlays :  {
#                     &quot;Band 7 (SWIR)&quot; : tile_layer_4769afa1d6a0896f3a29ad5938ff3bd6,
#                     &quot;Band 5 (NIR)&quot; : tile_layer_3e6db492f7c3b6fad3e8b6538720b63e,
#                     &quot;Band 4 (RED)&quot; : tile_layer_0a1e417474758fa7e48dfee30a9d5637,
#                 },
#             };
#             let layer_control_5e25bd2ee3a48c3bb66a6728429a6646 = L.control.layers(
#                 layer_control_5e25bd2ee3a48c3bb66a6728429a6646_layers.base_layers,
#                 layer_control_5e25bd2ee3a48c3bb66a6728429a6646_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_777478167064ce8e31e446db7a9aebaa);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Koreksi Atmosferik

# %% [markdown]
# ### Pathrow 124062 (Prefire)

# %%
import ee
import folium
import geemap.foliumap as geemap

#Fungsi agar folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)  #Mengambil URL peta dari objek citra EE dengan visualisasi tertentu

     #Menambahkan layer citra EE ke peta Folium menggunakan TileLayer
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format, # URL tile GEE
        attr='Google Earth Engine', #Atribut sumber tile
        name=name, #Nama layer untuk kontrol layer di peta
        overlay=True, #Menandakan ini layer tambahan, bukan base map
        control=True  #Memungkinkan kontrol layer aktif/nonaktif
    ).add_to(self) #Menambahkan layer ke map
folium.Map.add_ee_layer = add_ee_layer


# Filter Path/Row dan Tanggal
path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-01-01'
end_date = '2023-07-31'

#Ambil citra dari koleksi berdasarkan cloud cover terkecil
landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()

#Ambil metadata tanggal dan cloud cover
date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')

#DARK OBJECT SUBTRACTION (DOS)
def dark_object_subtraction(img, band_names): #memanggil band names di dark_object_substractiobn (B7,B5,B4)
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),  # mendekati nilai minimum
            geometry=band.geometry(),
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

#Terapkan DOS untuk band 7, 5, 4
dos_corrected = dark_object_subtraction(landsat9_toa, ['B7', 'B5', 'B4'])


false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}


m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'DOS False Color (B7-B5-B4)')
m.add_child(folium.LayerControl()) # Kontrol layer

#informasi tanggal dan cloud cover di atas peta
title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Koreksi Atmosferik (DOS) | Pathrow 124062 | Prefire
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Citra yang ditampilkan diambil pada tanggal: 2023-07-26
# Persentase Cloud Cover: 14.07%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93af26971e51129c73f6af4de10ffbbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Koreksi Atmosferik (DOS) | Pathrow 124062 | Prefire
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93af26971e51129c73f6af4de10ffbbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93af26971e51129c73f6af4de10ffbbc = L.map(
#                 &quot;map_93af26971e51129c73f6af4de10ffbbc&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d85d3f0291cb46aa3a623ba60361b91d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d85d3f0291cb46aa3a623ba60361b91d.addTo(map_93af26971e51129c73f6af4de10ffbbc);
#
#
#             var tile_layer_7fde4f026da2d9efc259da7b98a99d31 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/9bbfb93e5306568a6e923e75867093a9-8a19595275d6a3207326ebf1e77519d2/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7fde4f026da2d9efc259da7b98a99d31.addTo(map_93af26971e51129c73f6af4de10ffbbc);
#
#
#             var layer_control_6ad2ee262da1c52fd588cb3b66263fa8_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_d85d3f0291cb46aa3a623ba60361b91d,
#                 },
#                 overlays :  {
#                     &quot;DOS False Color (B7-B5-B4)&quot; : tile_layer_7fde4f026da2d9efc259da7b98a99d31,
#                 },
#             };
#             let layer_control_6ad2ee262da1c52fd588cb3b66263fa8 = L.control.layers(
#                 layer_control_6ad2ee262da1c52fd588cb3b66263fa8_layers.base_layers,
#                 layer_control_6ad2ee262da1c52fd588cb3b66263fa8_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_93af26971e51129c73f6af4de10ffbbc);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Pathrow 125062 (Prefire)

# %%
import ee
import folium
import geemap.foliumap as geemap


def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-01-01'
end_date = '2023-07-31'


landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()


date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')


def dark_object_subtraction(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),  # mendekati nilai minimum
            geometry=band.geometry(),
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)

    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())


dos_corrected = dark_object_subtraction(landsat9_toa, ['B7', 'B5', 'B4'])


false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}


m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'DOS False Color (B7-B5-B4)')
m.add_child(folium.LayerControl())


title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Koreksi Atmosferik (DOS) | Pathrow 125062 | Prefire
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Citra yang ditampilkan diambil pada tanggal: 2023-05-14
# Persentase Cloud Cover: 26.38%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9524592b8b80e716eeaab20d3ebfdd8c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Koreksi Atmosferik (DOS) | Pathrow 125062 | Prefire
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9524592b8b80e716eeaab20d3ebfdd8c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9524592b8b80e716eeaab20d3ebfdd8c = L.map(
#                 &quot;map_9524592b8b80e716eeaab20d3ebfdd8c&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c72ab27b09d951d0612ea9d238cc3897 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c72ab27b09d951d0612ea9d238cc3897.addTo(map_9524592b8b80e716eeaab20d3ebfdd8c);
#
#
#             var tile_layer_8aca08c83646f2927ce6f1df371ba4e8 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/2a803b8c54a51ddd489649db19929b13-b31df606282e7b7da7c90173006f7c2d/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8aca08c83646f2927ce6f1df371ba4e8.addTo(map_9524592b8b80e716eeaab20d3ebfdd8c);
#
#
#             var layer_control_05494f3df2956874fa7c39622829c056_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_c72ab27b09d951d0612ea9d238cc3897,
#                 },
#                 overlays :  {
#                     &quot;DOS False Color (B7-B5-B4)&quot; : tile_layer_8aca08c83646f2927ce6f1df371ba4e8,
#                 },
#             };
#             let layer_control_05494f3df2956874fa7c39622829c056 = L.control.layers(
#                 layer_control_05494f3df2956874fa7c39622829c056_layers.base_layers,
#                 layer_control_05494f3df2956874fa7c39622829c056_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_9524592b8b80e716eeaab20d3ebfdd8c);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Pathrow 124062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap


def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'


landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()


date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')


def dark_object_subtraction(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),  # mendekati nilai minimum
            geometry=band.geometry(),
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

dos_corrected = dark_object_subtraction(landsat9_toa, ['B7', 'B5', 'B4'])

false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}


m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'DOS False Color (B7-B5-B4)')
m.add_child(folium.LayerControl())


title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Koreksi Atmosferik (DOS) | Pathrow 124062 | Postfire
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Citra yang ditampilkan diambil pada tanggal: 2023-11-15
# Persentase Cloud Cover: 23.63%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25c9ac79402f194e5c31cd8c3ceafff4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Koreksi Atmosferik (DOS) | Pathrow 124062 | Postfire
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25c9ac79402f194e5c31cd8c3ceafff4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25c9ac79402f194e5c31cd8c3ceafff4 = L.map(
#                 &quot;map_25c9ac79402f194e5c31cd8c3ceafff4&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72e75d3535ef3270c2d87004ab10a9af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_72e75d3535ef3270c2d87004ab10a9af.addTo(map_25c9ac79402f194e5c31cd8c3ceafff4);
#
#
#             var tile_layer_7ec3d1221687af8112ffd1407abd3c69 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/df173ae7eb96cd0d2a292e387d3deb7f-e82d0d77e826c8e16767ef172dba0fb4/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ec3d1221687af8112ffd1407abd3c69.addTo(map_25c9ac79402f194e5c31cd8c3ceafff4);
#
#
#             var layer_control_1bec5488268f973b9ac2533a916d9b33_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_72e75d3535ef3270c2d87004ab10a9af,
#                 },
#                 overlays :  {
#                     &quot;DOS False Color (B7-B5-B4)&quot; : tile_layer_7ec3d1221687af8112ffd1407abd3c69,
#                 },
#             };
#             let layer_control_1bec5488268f973b9ac2533a916d9b33 = L.control.layers(
#                 layer_control_1bec5488268f973b9ac2533a916d9b33_layers.base_layers,
#                 layer_control_1bec5488268f973b9ac2533a916d9b33_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_25c9ac79402f194e5c31cd8c3ceafff4);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Pathrow 125062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap


def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

start_date = '2023-11-01'
end_date = '2023-12-31'


landsat9_toa = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .first()


date_acquired = landsat9_toa.get('DATE_ACQUIRED').getInfo()
cloud_cover = landsat9_toa.get('CLOUD_COVER').getInfo()
print(f'Citra yang ditampilkan diambil pada tanggal: {date_acquired}')
print(f'Persentase Cloud Cover: {cloud_cover}%')


def dark_object_subtraction(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),  # mendekati nilai minimum
            geometry=band.geometry(),
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

dos_corrected = dark_object_subtraction(landsat9_toa, ['B7', 'B5', 'B4'])


false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}


m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'DOS False Color (B7-B5-B4)')
m.add_child(folium.LayerControl())


title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Koreksi Atmosferik (DOS) | Pathrow 125062 | Postfire
     </b></h3>
     '''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Citra yang ditampilkan diambil pada tanggal: 2023-11-06
# Persentase Cloud Cover: 41.67%
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ede9b94ecc0fb126ae6e5c36d46d294 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Koreksi Atmosferik (DOS) | Pathrow 125062 | Postfire
#      &lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ede9b94ecc0fb126ae6e5c36d46d294&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ede9b94ecc0fb126ae6e5c36d46d294 = L.map(
#                 &quot;map_9ede9b94ecc0fb126ae6e5c36d46d294&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81f0f9dfba81d74484fa726afd1493d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81f0f9dfba81d74484fa726afd1493d0.addTo(map_9ede9b94ecc0fb126ae6e5c36d46d294);
#
#
#             var tile_layer_66b60bce69cdd70a9f50644c0aa456e2 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/c1e81fef399c7e0ec26bbb3a4a408a52-7510370e0a0721cf699f7cf2d306344a/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_66b60bce69cdd70a9f50644c0aa456e2.addTo(map_9ede9b94ecc0fb126ae6e5c36d46d294);
#
#
#             var layer_control_b13b593c8e30495d70c4006d77a045ef_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_81f0f9dfba81d74484fa726afd1493d0,
#                 },
#                 overlays :  {
#                     &quot;DOS False Color (B7-B5-B4)&quot; : tile_layer_66b60bce69cdd70a9f50644c0aa456e2,
#                 },
#             };
#             let layer_control_b13b593c8e30495d70c4006d77a045ef = L.control.layers(
#                 layer_control_b13b593c8e30495d70c4006d77a045ef_layers.base_layers,
#                 layer_control_b13b593c8e30495d70c4006d77a045ef_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_9ede9b94ecc0fb126ae6e5c36d46d294);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Cloud Masking

# %% [markdown]
# ### Tanpa Tambal

# %%
#TANPA TAMBAL

import ee
import folium
import geemap.foliumap as geemap

# Fungsi agar folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

# Pathrow dan rentang waktu data
path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-01-01'
end_date = '2023-07-31'

# Ambil koleksi citra LANDSAT 9 TOA
collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER')

# Pilih citra dengan cloud cover terendah
image_best = collection.first()
roi_geometry = image_best.geometry()

# DARK OBJECT SUBTRACTION (DOS)
def dos(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=roi_geometry,
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

def apply_dos(img):
    dos_img = dos(img, ['B7', 'B5', 'B4'])
    return dos_img.copyProperties(img, img.propertyNames())

dos_collection = collection.map(apply_dos)

# Fungsi Cloud Masking menggunakan QA_PIXEL
def cloudmask(dos_img):
    system_index = dos_img.get('system:index')
    original = collection.filter(ee.Filter.eq('system:index', system_index)).first()
    qa = original.select('QA_PIXEL')

    fill    = (1 << 0)
    dilated = (1 << 1)
    cirrus  = (1 << 2)
    cloud   = (1 << 3)
    shadow  = (1 << 4)
    snow    = (1 << 5)
    water   = (1 << 7)

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \
        .And(qa.bitwiseAnd(snow).eq(0)) \
        .And(qa.bitwiseAnd(water).eq(0))

    return dos_img.updateMask(mask)

# Terapkan masking awan
masked_dos_collection = dos_collection.map(cloudmask)
composite_after = masked_dos_collection.median()


false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}

m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(composite_after, false_color_vis, 'Cloud Masking (QA Bands)')
m.add_child(folium.LayerControl())

title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Cloud Masking | Pathrow 124062 | Prefire
     </b></h3>
'''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d02ec37c0879fe9447572a70ad5c13bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Cloud Masking | Pathrow 124062 | Prefire
#      &lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d02ec37c0879fe9447572a70ad5c13bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d02ec37c0879fe9447572a70ad5c13bc = L.map(
#                 &quot;map_d02ec37c0879fe9447572a70ad5c13bc&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46dac9a1f7adf1fef421ec6b1099eb9a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46dac9a1f7adf1fef421ec6b1099eb9a.addTo(map_d02ec37c0879fe9447572a70ad5c13bc);
#
#
#             var tile_layer_f7c7b4a8a4382e617856c2560a29224b = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/7e7d89f2ac15c3352d9c572fe3631984-82ef978222bac4e8626dc27b6812546b/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f7c7b4a8a4382e617856c2560a29224b.addTo(map_d02ec37c0879fe9447572a70ad5c13bc);
#
#
#             var layer_control_dd8954271f32173a267adc702f4a7e0c_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_46dac9a1f7adf1fef421ec6b1099eb9a,
#                 },
#                 overlays :  {
#                     &quot;Cloud Masking (QA Bands)&quot; : tile_layer_f7c7b4a8a4382e617856c2560a29224b,
#                 },
#             };
#             let layer_control_dd8954271f32173a267adc702f4a7e0c = L.control.layers(
#                 layer_control_dd8954271f32173a267adc702f4a7e0c_layers.base_layers,
#                 layer_control_dd8954271f32173a267adc702f4a7e0c_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_d02ec37c0879fe9447572a70ad5c13bc);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Pathrow 124062 (Prefire)

# %%
import ee
import folium
import geemap.foliumap as geemap

#Fungsi agar folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


#Pathrow dan rentang waktu data
path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-01-01'
end_date = '2023-07-31'

#Ambil koleksi citra LANDSAT 9 TOA berdasarkan Pathrow dan rentang waktu
collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER')

#Pilih citra dengan cloud cover terendah
image_best = collection.first() #Mengambil citra pertama dari Collection berdasarkan pathrow, rentang waktu dan cloudcover
roi_geometry = image_best.geometry() #ROI geometri berdasarkan image_best, membantu DOS hanya spesifik di ROI

#DARK OBJECT SUBTRACTION (DOS)
def dos(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=roi_geometry,
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

#Terapkan DOS pada setiap citra
def apply_dos(img):
    dos_img = dos(img, ['B7', 'B5', 'B4'])
    return dos_img.copyProperties(img, img.propertyNames())

#Koleksi hasil koreksi atmosferik (DOS)
dos_collection = collection.map(apply_dos)
composite_before = dos_collection.median()


# Fungsi Cloud Masking menggunakan QA_PIXEL dari citra asli
def cloudmask(dos_img):
    #Ambil system: index dari citra hasil DOS
    system_index = dos_img.get('system:index')
    #Ambil citra asli dari koleksi berdasarkan system:index
    original = collection.filter(ee.Filter.eq('system:index', system_index)).first()

    #Ambil band QA_PIXEL
    qa = original.select('QA_PIXEL')

    #Bit untuk masking kualitas citra dari QA_PIXEL
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan


    #Buat mask gabungan (piksel baik adalah yang tidak memiliki bit-bit tersebut)
    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0)) \

        # Update mask pada citra hasil DOS
    return dos_img.updateMask(mask)

# Terapkan masking awan ke citra hasil DOS
masked_dos_collection = dos_collection.map(cloudmask)

# Composite setelah masking (akan ada lubang karena masking)
composite_after = masked_dos_collection.median()

#Tambal lubang dengan composite sebelum masking
dos_corrected = composite_after.unmask(composite_before)

false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'Cloud Masking (QA Bands)')
m.add_child(folium.LayerControl())

title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Cloud Masking | Pathrow 124062 | Prefire
     </b></h3>
'''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca409ccaffea161a90f0e4ca0c999ddb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Cloud Masking | Pathrow 124062 | Prefire
#      &lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca409ccaffea161a90f0e4ca0c999ddb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca409ccaffea161a90f0e4ca0c999ddb = L.map(
#                 &quot;map_ca409ccaffea161a90f0e4ca0c999ddb&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bfc8302d4aea7394c35ababad31720a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bfc8302d4aea7394c35ababad31720a6.addTo(map_ca409ccaffea161a90f0e4ca0c999ddb);
#
#
#             var tile_layer_23e8fa560c32d08896800d03b4a7994f = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/2ec672f98aae2e6187950e3780aad544-c3d06e0cf2548b62d82e6face162bc3d/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_23e8fa560c32d08896800d03b4a7994f.addTo(map_ca409ccaffea161a90f0e4ca0c999ddb);
#
#
#             var layer_control_7350cf0a23f978337671af9833037cab_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_bfc8302d4aea7394c35ababad31720a6,
#                 },
#                 overlays :  {
#                     &quot;Cloud Masking (QA Bands)&quot; : tile_layer_23e8fa560c32d08896800d03b4a7994f,
#                 },
#             };
#             let layer_control_7350cf0a23f978337671af9833037cab = L.control.layers(
#                 layer_control_7350cf0a23f978337671af9833037cab_layers.base_layers,
#                 layer_control_7350cf0a23f978337671af9833037cab_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_ca409ccaffea161a90f0e4ca0c999ddb);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Pathrow 125062 (Prefire)

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-01-01'
end_date = '2023-07-31'


collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER')

image_best = collection.first()
roi_geometry = image_best.geometry()

def dos(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=roi_geometry,
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

def apply_dos(img):
    dos_img = dos(img, ['B7', 'B5', 'B4'])
    return dos_img.copyProperties(img, img.propertyNames())

dos_collection = collection.map(apply_dos)
composite_before = dos_collection.median()


def cloudmask(dos_img):
    system_index = dos_img.get('system:index')
    original = collection.filter(ee.Filter.eq('system:index', system_index)).first()
    qa = original.select('QA_PIXEL')
    #Bit untuk masking kualitas citra dari QA_PIXEL
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0))
    return dos_img.updateMask(mask)

masked_dos_collection = dos_collection.map(cloudmask)
composite_after = masked_dos_collection.median()
dos_corrected = composite_after.unmask(composite_before)

false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'Cloud Masking (QA Bands)')
m.add_child(folium.LayerControl())

title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Cloud Masking | Pathrow 125062 | Prefire
     </b></h3>
'''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0a9141612af411beb7420a94f58a01d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Cloud Masking | Pathrow 125062 | Prefire
#      &lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0a9141612af411beb7420a94f58a01d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0a9141612af411beb7420a94f58a01d = L.map(
#                 &quot;map_f0a9141612af411beb7420a94f58a01d&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c0f54a55b45195ab8cc3579e97d378c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c0f54a55b45195ab8cc3579e97d378c.addTo(map_f0a9141612af411beb7420a94f58a01d);
#
#
#             var tile_layer_8d374f09053a2b4473515c9743285d57 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/6db92be54799fb902cdcdb71b4411cea-5c5b5d850eb8ae88e62278a7eb32f163/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d374f09053a2b4473515c9743285d57.addTo(map_f0a9141612af411beb7420a94f58a01d);
#
#
#             var layer_control_2d94eaed0ef73db96ad5045fca21ae32_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_7c0f54a55b45195ab8cc3579e97d378c,
#                 },
#                 overlays :  {
#                     &quot;Cloud Masking (QA Bands)&quot; : tile_layer_8d374f09053a2b4473515c9743285d57,
#                 },
#             };
#             let layer_control_2d94eaed0ef73db96ad5045fca21ae32 = L.control.layers(
#                 layer_control_2d94eaed0ef73db96ad5045fca21ae32_layers.base_layers,
#                 layer_control_2d94eaed0ef73db96ad5045fca21ae32_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_f0a9141612af411beb7420a94f58a01d);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Pathrow 124062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'


collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER')

image_best = collection.first()
roi_geometry = image_best.geometry()

def dos(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=roi_geometry,
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

def apply_dos(img):
    dos_img = dos(img, ['B7', 'B5', 'B4'])
    return dos_img.copyProperties(img, img.propertyNames())

dos_collection = collection.map(apply_dos)
composite_before = dos_collection.median()


def cloudmask(dos_img):
    system_index = dos_img.get('system:index')
    original = collection.filter(ee.Filter.eq('system:index', system_index)).first()
    qa = original.select('QA_PIXEL')
    #Bit untuk masking kualitas citra dari QA_PIXEL
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0))
    return dos_img.updateMask(mask)

masked_dos_collection = dos_collection.map(cloudmask)
composite_after = masked_dos_collection.median()
dos_corrected = composite_after.unmask(composite_before)

false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'Cloud Masking (QA Bands)')
m.add_child(folium.LayerControl())

title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Cloud Masking | Pathrow 124062 | Postfire
     </b></h3>
'''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_593bcce63f88d44fa3407a71879d918e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Cloud Masking | Pathrow 124062 | Postfire
#      &lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_593bcce63f88d44fa3407a71879d918e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_593bcce63f88d44fa3407a71879d918e = L.map(
#                 &quot;map_593bcce63f88d44fa3407a71879d918e&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7893a5357f6b8fa4af68210577fb745d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7893a5357f6b8fa4af68210577fb745d.addTo(map_593bcce63f88d44fa3407a71879d918e);
#
#
#             var tile_layer_47280b71ba98b5dc261c76e2a771dd9b = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/eb8bdc378b662ef4522cf01ddb8920db-1faeac6d95f581ce14cba18959350e77/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_47280b71ba98b5dc261c76e2a771dd9b.addTo(map_593bcce63f88d44fa3407a71879d918e);
#
#
#             var layer_control_eff5b3b02e07d81ea31d7f754b8ca350_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_7893a5357f6b8fa4af68210577fb745d,
#                 },
#                 overlays :  {
#                     &quot;Cloud Masking (QA Bands)&quot; : tile_layer_47280b71ba98b5dc261c76e2a771dd9b,
#                 },
#             };
#             let layer_control_eff5b3b02e07d81ea31d7f754b8ca350 = L.control.layers(
#                 layer_control_eff5b3b02e07d81ea31d7f754b8ca350_layers.base_layers,
#                 layer_control_eff5b3b02e07d81ea31d7f754b8ca350_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_593bcce63f88d44fa3407a71879d918e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Pathrow 125062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'


collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER')

image_best = collection.first()
roi_geometry = image_best.geometry()

def dos(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=roi_geometry,
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

def apply_dos(img):
    dos_img = dos(img, ['B7', 'B5', 'B4'])
    return dos_img.copyProperties(img, img.propertyNames())

dos_collection = collection.map(apply_dos)
composite_before = dos_collection.median()


def cloudmask(dos_img):
    system_index = dos_img.get('system:index')
    original = collection.filter(ee.Filter.eq('system:index', system_index)).first()
    qa = original.select('QA_PIXEL')
    #Bit untuk masking kualitas citra dari QA_PIXEL
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0))
    return dos_img.updateMask(mask)

masked_dos_collection = dos_collection.map(cloudmask)
composite_after = masked_dos_collection.median()
dos_corrected = composite_after.unmask(composite_before)

false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'Cloud Masking (QA Bands)')
m.add_child(folium.LayerControl())

title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     Cloud Masking | Pathrow 125062 | Postfire
     </b></h3>
'''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a144e50eaa94dd3f5a3a0bec388ef3a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      Cloud Masking | Pathrow 125062 | Postfire
#      &lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a144e50eaa94dd3f5a3a0bec388ef3a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a144e50eaa94dd3f5a3a0bec388ef3a2 = L.map(
#                 &quot;map_a144e50eaa94dd3f5a3a0bec388ef3a2&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d58f61e21e778f508995541a496e192 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9d58f61e21e778f508995541a496e192.addTo(map_a144e50eaa94dd3f5a3a0bec388ef3a2);
#
#
#             var tile_layer_b83b93c6120b8e93584b1afc92a5617d = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/34d847d0f6dbcd065a10b9e9e1d0b234-73088a3734823c8338d16305c7b137f0/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b83b93c6120b8e93584b1afc92a5617d.addTo(map_a144e50eaa94dd3f5a3a0bec388ef3a2);
#
#
#             var layer_control_7e29d159e8a37b64bd4a353c583dedee_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_9d58f61e21e778f508995541a496e192,
#                 },
#                 overlays :  {
#                     &quot;Cloud Masking (QA Bands)&quot; : tile_layer_b83b93c6120b8e93584b1afc92a5617d,
#                 },
#             };
#             let layer_control_7e29d159e8a37b64bd4a353c583dedee = L.control.layers(
#                 layer_control_7e29d159e8a37b64bd4a353c583dedee_layers.base_layers,
#                 layer_control_7e29d159e8a37b64bd4a353c583dedee_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_a144e50eaa94dd3f5a3a0bec388ef3a2);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Komposit Citra

# %% [markdown]
# ### False color 7-5-4 (Postfire) | 124

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'


collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER')

image_best = collection.first()
roi_geometry = image_best.geometry()

def dos(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=roi_geometry,
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

def apply_dos(img):
    dos_img = dos(img, ['B7', 'B5', 'B4'])
    return dos_img.copyProperties(img, img.propertyNames())

dos_collection = collection.map(apply_dos)
composite_before = dos_collection.median()


def cloudmask(dos_img):
    system_index = dos_img.get('system:index')
    original = collection.filter(ee.Filter.eq('system:index', system_index)).first()
    qa = original.select('QA_PIXEL')
    #Bit untuk masking kualitas citra dari QA_PIXEL
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0))
    return dos_img.updateMask(mask)

masked_dos_collection = dos_collection.map(cloudmask)
composite_after = masked_dos_collection.median()
dos_corrected = composite_after.unmask(composite_before)

false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'Cloud Masking (QA Bands)')
m.add_child(folium.LayerControl())

title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     False Color | Pathrow 124062 | Postfire
     </b></h3>
'''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_221921f7f9f96cd89e8016b78dafe01a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      False Color | Pathrow 124062 | Postfire
#      &lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_221921f7f9f96cd89e8016b78dafe01a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_221921f7f9f96cd89e8016b78dafe01a = L.map(
#                 &quot;map_221921f7f9f96cd89e8016b78dafe01a&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1853b5d73622c9df2270a037fe31336e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1853b5d73622c9df2270a037fe31336e.addTo(map_221921f7f9f96cd89e8016b78dafe01a);
#
#
#             var tile_layer_186e44ba6da85cd139908684d71feca5 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/eb8bdc378b662ef4522cf01ddb8920db-221d5d7b41b553d802e523bc9e3129b4/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_186e44ba6da85cd139908684d71feca5.addTo(map_221921f7f9f96cd89e8016b78dafe01a);
#
#
#             var layer_control_8b5fa038f2000df14cb6103887eb2bed_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_1853b5d73622c9df2270a037fe31336e,
#                 },
#                 overlays :  {
#                     &quot;Cloud Masking (QA Bands)&quot; : tile_layer_186e44ba6da85cd139908684d71feca5,
#                 },
#             };
#             let layer_control_8b5fa038f2000df14cb6103887eb2bed = L.control.layers(
#                 layer_control_8b5fa038f2000df14cb6103887eb2bed_layers.base_layers,
#                 layer_control_8b5fa038f2000df14cb6103887eb2bed_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_221921f7f9f96cd89e8016b78dafe01a);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### False Color 7-5-4 (Postfire) | 125

# %%
import ee
import folium
import geemap.foliumap as geemap

def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'


collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER')

image_best = collection.first()
roi_geometry = image_best.geometry()

def dos(img, band_names):
    def subtract_min(band_name):
        band = img.select(band_name)
        dark_object = band.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=roi_geometry,
            scale=30,
            maxPixels=1e9
        ).get(band_name)
        return band.subtract(ee.Number(dark_object)).rename(band_name)
    corrected_bands = [subtract_min(b) for b in band_names]
    return ee.Image.cat(corrected_bands).copyProperties(img, img.propertyNames())

def apply_dos(img):
    dos_img = dos(img, ['B7', 'B5', 'B4'])
    return dos_img.copyProperties(img, img.propertyNames())

dos_collection = collection.map(apply_dos)
composite_before = dos_collection.median()


def cloudmask(dos_img):
    system_index = dos_img.get('system:index')
    original = collection.filter(ee.Filter.eq('system:index', system_index)).first()
    qa = original.select('QA_PIXEL')
    #Bit untuk masking kualitas citra dari QA_PIXEL
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0))
    return dos_img.updateMask(mask)

masked_dos_collection = dos_collection.map(cloudmask)
composite_after = masked_dos_collection.median()
dos_corrected = composite_after.unmask(composite_before)

false_color_vis = {
    'bands': ['B7', 'B5', 'B4'],
    'min': 0.0,
    'max': 0.5,
}
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dos_corrected, false_color_vis, 'Cloud Masking (QA Bands)')
m.add_child(folium.LayerControl())

title_html = f'''
    <h3 align="center" style="font-size:20px"><b>
     False Color | Pathrow 125062 | Postfire
     </b></h3>
'''
m.get_root().html.add_child(folium.Element(title_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1715e76a9040b5b47cabd49a95d54c95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;
#      False Color | Pathrow 125062 | Postfire
#      &lt;/b&gt;&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1715e76a9040b5b47cabd49a95d54c95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1715e76a9040b5b47cabd49a95d54c95 = L.map(
#                 &quot;map_1715e76a9040b5b47cabd49a95d54c95&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b363744d81ba1ed993ee3249e24ca1ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b363744d81ba1ed993ee3249e24ca1ea.addTo(map_1715e76a9040b5b47cabd49a95d54c95);
#
#
#             var tile_layer_07bed21052702e38fc6f9fbfd93b2d86 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/34d847d0f6dbcd065a10b9e9e1d0b234-fb8c5916a4fc18e6d3819617e742f893/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07bed21052702e38fc6f9fbfd93b2d86.addTo(map_1715e76a9040b5b47cabd49a95d54c95);
#
#
#             var layer_control_c65ff44faae2681161a5b9b5dadd983a_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_b363744d81ba1ed993ee3249e24ca1ea,
#                 },
#                 overlays :  {
#                     &quot;Cloud Masking (QA Bands)&quot; : tile_layer_07bed21052702e38fc6f9fbfd93b2d86,
#                 },
#             };
#             let layer_control_c65ff44faae2681161a5b9b5dadd983a = L.control.layers(
#                 layer_control_c65ff44faae2681161a5b9b5dadd983a_layers.base_layers,
#                 layer_control_c65ff44faae2681161a5b9b5dadd983a_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_1715e76a9040b5b47cabd49a95d54c95);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Ekstraksi Fitur

# %% [markdown]
# ## NDVI Pathrow 124062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap

# Fungsi agar folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

#Filter lokasi dan waktu
path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'


# Fungsi DOS
def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)

#Fungsi Masking awan QA_PIXEL
def mask_fmask(image):
    qa = image.select('QA_PIXEL')

    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0))

    return image.updateMask(mask)

# ========================================
# Ambil koleksi dan terapkan DOS
collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)

# Hitung NDVI dari citra mentah (penambal)
ndvi_fill = collection.map(lambda img: img.normalizedDifference(['B5', 'B4']).rename('NDVI')).median()

# Masking awan
masked_collection = collection.map(mask_fmask)

# Hitung NDVI dari citra yang sudah di-mask
ndvi_masked = masked_collection.map(lambda img: img.normalizedDifference(['B5', 'B4']).rename('NDVI'))
ndvi_composite = ndvi_masked.median()

# Ambil geometri dari image pertama
first_image = collection.first()
geometry = first_image.geometry()

# Unmask bagian berlubang dan clip ke ROI
ndvi_filled = ndvi_composite.unmask(ndvi_fill).clip(geometry)

# ========================================
# Visualisasi NDVI
ndvi_vis_params = {
    'min': -1,
    'max': 1,
    'palette': ['red', 'orange', 'yellow', 'green', 'darkgreen']
}

# ========================================
# Tampilkan ke peta dengan FOLIUM
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(ndvi_filled, ndvi_vis_params, 'NDVI Pathrow 124062')

# Tambahkan Layer Control
m.add_child(folium.LayerControl())

# ========================================
# Tambahkan Legenda NDVI
legend_keys = [
    '< 0: Non Vegetasi',
    '0 - 0.2: Vegetasi Sangat Jarang',
    '0.2 - 0.4: Vegetasi Rendah',
    '0.4 - 0.6: Vegetasi Sedang-Lebat',
    '> 0.6: Vegetasi Sangat Lebat'
]

legend_colors = [
    (255, 0, 0),         # red
    (255, 165, 0),       # orange
    (255, 255, 0),       # yellow
    (0, 128, 0),         # green
    (0, 100, 0)          # darkgreen
]

legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>NDVI pathrow 124062</b><br>
'''

for label, color in zip(legend_keys, legend_colors):
    rgb = f'rgb{color}'
    legend_html += f'<i style="background:{rgb};width:12px;height:12px;display:inline-block;margin-right:6px;"></i>{label}<br>'

legend_html += '</div>'
m.get_root().html.add_child(folium.Element(legend_html))

# Tampilkan Peta
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe73bc432de5fe129c2e49cded09c12d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;NDVI pathrow 124062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(255, 0, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&lt; 0: Non Vegetasi&lt;br&gt;&lt;i style=&quot;background:rgb(255, 165, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0 - 0.2: Vegetasi Sangat Jarang&lt;br&gt;&lt;i style=&quot;background:rgb(255, 255, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.2 - 0.4: Vegetasi Rendah&lt;br&gt;&lt;i style=&quot;background:rgb(0, 128, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.4 - 0.6: Vegetasi Sedang-Lebat&lt;br&gt;&lt;i style=&quot;background:rgb(0, 100, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&gt; 0.6: Vegetasi Sangat Lebat&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe73bc432de5fe129c2e49cded09c12d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe73bc432de5fe129c2e49cded09c12d = L.map(
#                 &quot;map_fe73bc432de5fe129c2e49cded09c12d&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec4315b3298f0a13042a73099394ed87 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec4315b3298f0a13042a73099394ed87.addTo(map_fe73bc432de5fe129c2e49cded09c12d);
#
#
#             var tile_layer_cb287ce15717ede8fbc0794db7d8d68e = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/86039651dbca8ce851307cc20f5a21d1-ed50285c7c4fb74d03178db15d773620/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb287ce15717ede8fbc0794db7d8d68e.addTo(map_fe73bc432de5fe129c2e49cded09c12d);
#
#
#             var layer_control_b4a53fd0e8f9b1b481fed7bf46e16319_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_ec4315b3298f0a13042a73099394ed87,
#                 },
#                 overlays :  {
#                     &quot;NDVI Pathrow 124062&quot; : tile_layer_cb287ce15717ede8fbc0794db7d8d68e,
#                 },
#             };
#             let layer_control_b4a53fd0e8f9b1b481fed7bf46e16319 = L.control.layers(
#                 layer_control_b4a53fd0e8f9b1b481fed7bf46e16319_layers.base_layers,
#                 layer_control_b4a53fd0e8f9b1b481fed7bf46e16319_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_fe73bc432de5fe129c2e49cded09c12d);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## NDVI Pathrow 125062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap


def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer


path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'


def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)

def mask_fmask(image):
    qa = image.select('QA_PIXEL')
    fill    = (1 << 0)  # Bit 0: piksel kosong (invalid)
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan
    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0))

    return image.updateMask(mask)


collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)

ndvi_fill = collection.map(lambda img: img.normalizedDifference(['B5', 'B4']).rename('NDVI')).median()

masked_collection = collection.map(mask_fmask)


ndvi_masked = masked_collection.map(lambda img: img.normalizedDifference(['B5', 'B4']).rename('NDVI'))
ndvi_composite = ndvi_masked.median()


first_image = collection.first()
geometry = first_image.geometry()
ndvi_filled = ndvi_composite.unmask(ndvi_fill).clip(geometry)


# Visualisasi NDVI
ndvi_vis_params = {
    'min': -1,
    'max': 1,
    'palette': ['red', 'orange', 'yellow', 'green', 'darkgreen']
}


# Tampilkan ke peta dengan FOLIUM
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(ndvi_filled, ndvi_vis_params, 'NDVI Pathrow 124062')
m.add_child(folium.LayerControl())

# Tambahkan Legenda NDVI
legend_keys = [
    '< 0: Non Vegetasi',
    '0 - 0.2: Vegetasi Sangat Jarang',
    '0.2 - 0.4: Vegetasi Rendah',
    '0.4 - 0.6: Vegetasi Sedang-Lebat',
    '> 0.6: Vegetasi Sangat Lebat'
]

legend_colors = [
    (255, 0, 0),         # red
    (255, 165, 0),       # orange
    (255, 255, 0),       # yellow
    (0, 128, 0),         # green
    (0, 100, 0)          # darkgreen
]

legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>NDVI Pathrow 125062</b><br>
'''

for label, color in zip(legend_keys, legend_colors):
    rgb = f'rgb{color}'
    legend_html += f'<i style="background:{rgb};width:12px;height:12px;display:inline-block;margin-right:6px;"></i>{label}<br>'

legend_html += '</div>'
m.get_root().html.add_child(folium.Element(legend_html))
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dca3bea836993a6e4b9b9efc5cd1403e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;NDVI Pathrow 125062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(255, 0, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&lt; 0: Non Vegetasi&lt;br&gt;&lt;i style=&quot;background:rgb(255, 165, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0 - 0.2: Vegetasi Sangat Jarang&lt;br&gt;&lt;i style=&quot;background:rgb(255, 255, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.2 - 0.4: Vegetasi Rendah&lt;br&gt;&lt;i style=&quot;background:rgb(0, 128, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.4 - 0.6: Vegetasi Sedang-Lebat&lt;br&gt;&lt;i style=&quot;background:rgb(0, 100, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&gt; 0.6: Vegetasi Sangat Lebat&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dca3bea836993a6e4b9b9efc5cd1403e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dca3bea836993a6e4b9b9efc5cd1403e = L.map(
#                 &quot;map_dca3bea836993a6e4b9b9efc5cd1403e&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9467ea3fb16b96917d3f03a55f758629 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9467ea3fb16b96917d3f03a55f758629.addTo(map_dca3bea836993a6e4b9b9efc5cd1403e);
#
#
#             var tile_layer_bcc45100b2cac260c3ecba10264ddebe = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/ad1421207472395d312e6997f2cc8c62-13f37affe62594402e8571abc75f3abc/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bcc45100b2cac260c3ecba10264ddebe.addTo(map_dca3bea836993a6e4b9b9efc5cd1403e);
#
#
#             var layer_control_7dc0a0bab69e30da602cb9bd5fa7b921_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_9467ea3fb16b96917d3f03a55f758629,
#                 },
#                 overlays :  {
#                     &quot;NDVI Pathrow 124062&quot; : tile_layer_bcc45100b2cac260c3ecba10264ddebe,
#                 },
#             };
#             let layer_control_7dc0a0bab69e30da602cb9bd5fa7b921 = L.control.layers(
#                 layer_control_7dc0a0bab69e30da602cb9bd5fa7b921_layers.base_layers,
#                 layer_control_7dc0a0bab69e30da602cb9bd5fa7b921_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_dca3bea836993a6e4b9b9efc5cd1403e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## NBR Pathrow 124062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap

# =========================
# Fungsi agar folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

# =========================
# Filter lokasi dan waktu
path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'

# =========================
# Fungsi koreksi atmosfer Dark Object Subtraction (DOS1)
def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)

# =========================
# Fungsi masking awan berdasarkan QA_PIXEL
def mask_fmask(image):
    qa = image.select('QA_PIXEL')
    fill    = (1 << 0)  # Bit 0: piksel kosong
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0))

    return image.updateMask(mask)

# =========================
# Ambil koleksi citra dan terapkan DOS
collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)

# Hitung NBR dari citra mentah untuk penambal lubang
nbr_fill = collection.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()

# Masking awan
masked_collection = collection.map(mask_fmask)

# Hitung NBR dari citra yang sudah di-mask
nbr_masked = masked_collection.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
nbr_composite = nbr_masked.median()

# Ambil geometri dari citra pertama
first_image = collection.first()
geometry = first_image.geometry()

# Unmask bagian berlubang dan clip ke ROI
nbr_filled = nbr_composite.unmask(nbr_fill).clip(geometry)

# =========================
# Parameter visualisasi NBR
nbr_vis_params = {
    'min': -1,
    'max': 1,
    'palette': ['red', 'orange', 'yellow', 'green', 'darkgreen']
}

# =========================
# Tampilkan ke peta
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(nbr_filled, nbr_vis_params, 'NBR Pathrow 124062')
m.add_child(folium.LayerControl())

# Tambahkan Legenda NBR
legend_keys = [
    '< 0: Non Vegetasi',
    '0 - 0.2: Vegetasi Sangat Jarang',
    '0.2 - 0.4: Vegetasi Rendah',
    '0.4 - 0.6: Vegetasi Sedang-Lebat',
    '> 0.6: Vegetasi Sangat Lebat'
]

legend_colors = [
    (255, 0, 0),         # red
    (255, 165, 0),       # orange
    (255, 255, 0),       # yellow
    (0, 128, 0),         # green
    (0, 100, 0)          # darkgreen
]


legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>NBR Pathrow 124062</b><br>
'''

for label, color in zip(legend_keys, legend_colors):
    rgb = f'rgb{color}'
    legend_html += f'<i style="background:{rgb};width:12px;height:12px;display:inline-block;margin-right:6px;"></i>{label}<br>'

legend_html += '</div>'
m.get_root().html.add_child(folium.Element(legend_html))

# =========================
# Tampilkan peta interaktif
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52cd507f1b3e3b357d065fb83a0cdc29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;NBR Pathrow 124062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(255, 0, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&lt; 0: Non Vegetasi&lt;br&gt;&lt;i style=&quot;background:rgb(255, 165, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0 - 0.2: Vegetasi Sangat Jarang&lt;br&gt;&lt;i style=&quot;background:rgb(255, 255, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.2 - 0.4: Vegetasi Rendah&lt;br&gt;&lt;i style=&quot;background:rgb(0, 128, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.4 - 0.6: Vegetasi Sedang-Lebat&lt;br&gt;&lt;i style=&quot;background:rgb(0, 100, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&gt; 0.6: Vegetasi Sangat Lebat&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52cd507f1b3e3b357d065fb83a0cdc29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52cd507f1b3e3b357d065fb83a0cdc29 = L.map(
#                 &quot;map_52cd507f1b3e3b357d065fb83a0cdc29&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1d9a73fa5f3febb4b5c239b7a7684517 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1d9a73fa5f3febb4b5c239b7a7684517.addTo(map_52cd507f1b3e3b357d065fb83a0cdc29);
#
#
#             var tile_layer_12306120d345e8d81e90f2aeb9ee39b8 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/c780a2e362f2f38fde80543b1dc58b26-3c7aeb399cc8b67a99fa50b755abb663/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_12306120d345e8d81e90f2aeb9ee39b8.addTo(map_52cd507f1b3e3b357d065fb83a0cdc29);
#
#
#             var layer_control_8c8a1b15aac72031462288abeb0c868f_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_1d9a73fa5f3febb4b5c239b7a7684517,
#                 },
#                 overlays :  {
#                     &quot;NBR Pathrow 124062&quot; : tile_layer_12306120d345e8d81e90f2aeb9ee39b8,
#                 },
#             };
#             let layer_control_8c8a1b15aac72031462288abeb0c868f = L.control.layers(
#                 layer_control_8c8a1b15aac72031462288abeb0c868f_layers.base_layers,
#                 layer_control_8c8a1b15aac72031462288abeb0c868f_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_52cd507f1b3e3b357d065fb83a0cdc29);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## NBR Pathrow 125062 (Postfire)

# %%
import ee
import folium
import geemap.foliumap as geemap

# =========================
# Fungsi agar folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

# =========================
# Filter lokasi dan waktu
path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)
start_date = '2023-11-01'
end_date = '2023-12-31'

# =========================
# Fungsi koreksi atmosfer Dark Object Subtraction (DOS1)
def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)

# =========================
# Fungsi masking awan berdasarkan QA_PIXEL
def mask_fmask(image):
    qa = image.select('QA_PIXEL')
    fill    = (1 << 0)  # Bit 0: piksel kosong
    dilated = (1 << 1)  # Bit 1: buffer awan
    cirrus  = (1 << 2)  # Bit 2: awan tipis
    cloud   = (1 << 3)  # Bit 3: awan
    shadow  = (1 << 4)  # Bit 4: bayangan awan

    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0))

    return image.updateMask(mask)

# =========================
# Ambil koleksi citra dan terapkan DOS
collection = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(start_date, end_date) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)

# Hitung NBR dari citra mentah untuk penambal lubang
nbr_fill = collection.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()

# Masking awan
masked_collection = collection.map(mask_fmask)

# Hitung NBR dari citra yang sudah di-mask
nbr_masked = masked_collection.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
nbr_composite = nbr_masked.median()

# Ambil geometri dari citra pertama
first_image = collection.first()
geometry = first_image.geometry()

# Unmask bagian berlubang dan clip ke ROI
nbr_filled = nbr_composite.unmask(nbr_fill).clip(geometry)

# =========================
# Parameter visualisasi NBR
nbr_vis_params = {
    'min': -1,
    'max': 1,
    'palette': ['red', 'orange', 'yellow', 'green', 'darkgreen']
}

# =========================
# Tampilkan ke peta
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(nbr_filled, nbr_vis_params, 'NBR Pathrow 124062')
m.add_child(folium.LayerControl())

# Tambahkan Legenda NBR
legend_keys = [
    '< 0: Non Vegetasi',
    '0 - 0.2: Vegetasi Sangat Jarang',
    '0.2 - 0.4: Vegetasi Rendah',
    '0.4 - 0.6: Vegetasi Sedang-Lebat',
    '> 0.6: Vegetasi Sangat Lebat'
]

legend_colors = [
    (255, 0, 0),         # red
    (255, 165, 0),       # orange
    (255, 255, 0),       # yellow
    (0, 128, 0),         # green
    (0, 100, 0)          # darkgreen
]


legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>NBR Pathrow 125062</b><br>
'''

for label, color in zip(legend_keys, legend_colors):
    rgb = f'rgb{color}'
    legend_html += f'<i style="background:{rgb};width:12px;height:12px;display:inline-block;margin-right:6px;"></i>{label}<br>'

legend_html += '</div>'
m.get_root().html.add_child(folium.Element(legend_html))

# =========================
# Tampilkan peta interaktif
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_07063e2fbf2c56dd4193dc182896b404 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;NBR Pathrow 125062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(255, 0, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&lt; 0: Non Vegetasi&lt;br&gt;&lt;i style=&quot;background:rgb(255, 165, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0 - 0.2: Vegetasi Sangat Jarang&lt;br&gt;&lt;i style=&quot;background:rgb(255, 255, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.2 - 0.4: Vegetasi Rendah&lt;br&gt;&lt;i style=&quot;background:rgb(0, 128, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.4 - 0.6: Vegetasi Sedang-Lebat&lt;br&gt;&lt;i style=&quot;background:rgb(0, 100, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&gt; 0.6: Vegetasi Sangat Lebat&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_07063e2fbf2c56dd4193dc182896b404&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_07063e2fbf2c56dd4193dc182896b404 = L.map(
#                 &quot;map_07063e2fbf2c56dd4193dc182896b404&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8331d1180479de92e66d9deb914611f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8331d1180479de92e66d9deb914611f2.addTo(map_07063e2fbf2c56dd4193dc182896b404);
#
#
#             var tile_layer_52725f282a24466121e1289c75c697f1 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/1723d2937047ccceab0bd1bf15c17761-9892eed4c76ae3d37a8c174001dce88c/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_52725f282a24466121e1289c75c697f1.addTo(map_07063e2fbf2c56dd4193dc182896b404);
#
#
#             var layer_control_0a7fc413f16d3bcb50be399a8c72d9f2_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_8331d1180479de92e66d9deb914611f2,
#                 },
#                 overlays :  {
#                     &quot;NBR Pathrow 124062&quot; : tile_layer_52725f282a24466121e1289c75c697f1,
#                 },
#             };
#             let layer_control_0a7fc413f16d3bcb50be399a8c72d9f2 = L.control.layers(
#                 layer_control_0a7fc413f16d3bcb50be399a8c72d9f2_layers.base_layers,
#                 layer_control_0a7fc413f16d3bcb50be399a8c72d9f2_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_07063e2fbf2c56dd4193dc182896b404);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## DNBR

# %% [markdown]
# ### 124062

# %%
import ee
import folium
import geemap.foliumap as geemap

# =========================
# Fungsi agar folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

# =========================
# Parameter lokasi dan waktu
path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

# Prefire dan postfire
prefire_start = '2023-01-01'
prefire_end   = '2023-07-31'
postfire_start = '2023-11-01'
postfire_end   = '2023-12-31'

# =========================
# Fungsi koreksi atmosfer Dark Object Subtraction (DOS1)
def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)

# =========================
# Fungsi masking awan
def mask_fmask(image):
    qa = image.select('QA_PIXEL')
    fill    = (1 << 0)
    dilated = (1 << 1)
    cirrus  = (1 << 2)
    cloud   = (1 << 3)
    shadow  = (1 << 4)
    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0))
    return image.updateMask(mask)

# =========================
# Ambil koleksi prefire
prefire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(prefire_start, prefire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
prefire_fill = prefire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
prefire_masked = prefire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
prefire_nbr = prefire_masked.median().unmask(prefire_fill)

# Ambil koleksi postfire
postfire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(postfire_start, postfire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
postfire_fill = postfire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
postfire_masked = postfire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
postfire_nbr = postfire_masked.median().unmask(postfire_fill)

# Hitung dNBR
dnbr = prefire_nbr.subtract(postfire_nbr).rename('dNBR')

# =========================
# Visualisasi dNBR
dnbr_vis_params = {
    'min': -0.2,
    'max': 1,
    'palette': ['green', 'yellow', 'orange', 'red', 'black']
}

# =========================
# Peta
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dnbr, dnbr_vis_params, 'dNBR')
m.add_child(folium.LayerControl())

# =========================
# Legenda dNBR (4 kelas)
legend_keys = [
    '< 0.1: Tidak Terbakar',
    '0.1 - 0.27: Keparahan Rendah',
    '0.1 - 0.27: Keparahan Rendah-Sedang',
    '0.27 - 0.66: Keparahan Sedang-Tinggi',
    '> 0.66: Keparahan Tinggi'
]

legend_colors = [
    (0, 100, 0),       # darkgreen
    (0, 128, 0),       # darkgreen
    (255, 255, 0),     # yellow
    (255, 165, 0),     # orange
    (255, 0, 0),       # red
]

legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>dNBR Pathrow 124062</b><br>
'''

for label, color in zip(legend_keys, legend_colors):
    rgb = f'rgb{color}'
    legend_html += f'<i style="background:{rgb};width:12px;height:12px;display:inline-block;margin-right:6px;"></i>{label}<br>'

legend_html += '</div>'
m.get_root().html.add_child(folium.Element(legend_html))

# =========================
# Tampilkan
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c35d139a1b811386f1a1c2f64ad0a04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;dNBR Pathrow 124062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(0, 100, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&lt; 0.1: Tidak Terbakar&lt;br&gt;&lt;i style=&quot;background:rgb(0, 128, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.1 - 0.27: Keparahan Rendah&lt;br&gt;&lt;i style=&quot;background:rgb(255, 255, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.1 - 0.27: Keparahan Rendah-Sedang&lt;br&gt;&lt;i style=&quot;background:rgb(255, 165, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.27 - 0.66: Keparahan Sedang-Tinggi&lt;br&gt;&lt;i style=&quot;background:rgb(255, 0, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&gt; 0.66: Keparahan Tinggi&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c35d139a1b811386f1a1c2f64ad0a04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c35d139a1b811386f1a1c2f64ad0a04 = L.map(
#                 &quot;map_1c35d139a1b811386f1a1c2f64ad0a04&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5e03169938d89b95be1909c9619e34f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a5e03169938d89b95be1909c9619e34f.addTo(map_1c35d139a1b811386f1a1c2f64ad0a04);
#
#
#             var tile_layer_9141b727a5b6aa8ddd9b5243dc1d8f1a = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/a9a15cc2c6d0a0cb8e858bfe4c99a399-97adc5be58e9287ff9d30ad0987df5d2/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9141b727a5b6aa8ddd9b5243dc1d8f1a.addTo(map_1c35d139a1b811386f1a1c2f64ad0a04);
#
#
#             var layer_control_55cabdc3b86ba8f7d4558b587c78c823_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a5e03169938d89b95be1909c9619e34f,
#                 },
#                 overlays :  {
#                     &quot;dNBR&quot; : tile_layer_9141b727a5b6aa8ddd9b5243dc1d8f1a,
#                 },
#             };
#             let layer_control_55cabdc3b86ba8f7d4558b587c78c823 = L.control.layers(
#                 layer_control_55cabdc3b86ba8f7d4558b587c78c823_layers.base_layers,
#                 layer_control_55cabdc3b86ba8f7d4558b587c78c823_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_1c35d139a1b811386f1a1c2f64ad0a04);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 125062

# %%
import ee
import folium
import geemap.foliumap as geemap

# =========================
# Fungsi agar folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

# =========================
# Parameter lokasi dan waktu
path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

# Prefire dan postfire
prefire_start = '2023-01-01'
prefire_end   = '2023-07-31'
postfire_start = '2023-11-01'
postfire_end   = '2023-12-31'

# =========================
# Fungsi koreksi atmosfer Dark Object Subtraction (DOS1)
def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)

# =========================
# Fungsi masking awan
def mask_fmask(image):
    qa = image.select('QA_PIXEL')
    fill    = (1 << 0)
    dilated = (1 << 1)
    cirrus  = (1 << 2)
    cloud   = (1 << 3)
    shadow  = (1 << 4)
    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0))
    return image.updateMask(mask)

# =========================
# Ambil koleksi prefire
prefire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(prefire_start, prefire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
prefire_fill = prefire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
prefire_masked = prefire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
prefire_nbr = prefire_masked.median().unmask(prefire_fill)

# Ambil koleksi postfire
postfire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(postfire_start, postfire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
postfire_fill = postfire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
postfire_masked = postfire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
postfire_nbr = postfire_masked.median().unmask(postfire_fill)

# Hitung dNBR
dnbr = prefire_nbr.subtract(postfire_nbr).rename('dNBR')

# =========================
# Visualisasi dNBR
dnbr_vis_params = {
    'min': -0.2,
    'max': 1,
    'palette': ['green', 'yellow', 'orange', 'red', 'black']
}

# =========================
# Peta
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dnbr, dnbr_vis_params, 'dNBR')
m.add_child(folium.LayerControl())

# =========================
# Legenda dNBR (4 kelas)
legend_keys = [
    '< 0.1: Tidak Terbakar',
    '0.1 - 0.27: Keparahan Rendah',
    '0.1 - 0.27: Keparahan Rendah-Sedang',
    '0.27 - 0.66: Keparahan Sedang-Tinggi',
    '> 0.66: Keparahan Tinggi'
]

legend_colors = [
    (0, 100, 0),       # darkgreen
    (0, 128, 0),       # darkgreen
    (255, 255, 0),     # yellow
    (255, 165, 0),     # orange
    (255, 0, 0),       # red
]

legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>dNBR Pathrow 125062</b><br>
'''

for label, color in zip(legend_keys, legend_colors):
    rgb = f'rgb{color}'
    legend_html += f'<i style="background:{rgb};width:12px;height:12px;display:inline-block;margin-right:6px;"></i>{label}<br>'

legend_html += '</div>'
m.get_root().html.add_child(folium.Element(legend_html))

# =========================
# Tampilkan
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f833d482df466b0d6f227924af6aa602 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;dNBR Pathrow 125062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(0, 100, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&lt; 0.1: Tidak Terbakar&lt;br&gt;&lt;i style=&quot;background:rgb(0, 128, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.1 - 0.27: Keparahan Rendah&lt;br&gt;&lt;i style=&quot;background:rgb(255, 255, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.1 - 0.27: Keparahan Rendah-Sedang&lt;br&gt;&lt;i style=&quot;background:rgb(255, 165, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;0.27 - 0.66: Keparahan Sedang-Tinggi&lt;br&gt;&lt;i style=&quot;background:rgb(255, 0, 0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;&gt; 0.66: Keparahan Tinggi&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f833d482df466b0d6f227924af6aa602&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f833d482df466b0d6f227924af6aa602 = L.map(
#                 &quot;map_f833d482df466b0d6f227924af6aa602&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_937a9bbb1689c68b9eccd89f82a4fbef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_937a9bbb1689c68b9eccd89f82a4fbef.addTo(map_f833d482df466b0d6f227924af6aa602);
#
#
#             var tile_layer_64fe92f9f4a6dc9cdc8377a562712a82 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/2447c173bfb811dd1bcadba0aa620cbf-44ad9447c93e9a6b655b0a926de8acc1/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_64fe92f9f4a6dc9cdc8377a562712a82.addTo(map_f833d482df466b0d6f227924af6aa602);
#
#
#             var layer_control_544d83fddbbf3d851088685085f494f0_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_937a9bbb1689c68b9eccd89f82a4fbef,
#                 },
#                 overlays :  {
#                     &quot;dNBR&quot; : tile_layer_64fe92f9f4a6dc9cdc8377a562712a82,
#                 },
#             };
#             let layer_control_544d83fddbbf3d851088685085f494f0 = L.control.layers(
#                 layer_control_544d83fddbbf3d851088685085f494f0_layers.base_layers,
#                 layer_control_544d83fddbbf3d851088685085f494f0_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_f833d482df466b0d6f227924af6aa602);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Masking Citra

# %% [markdown]
# ### 124062

# %%
import ee
import folium
import geemap.foliumap as geemap

# =========================
# Fungsi agar folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

# =========================
# Parameter lokasi dan waktu
path_filter = ee.Filter.eq('WRS_PATH', 124)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

# Prefire dan postfire
prefire_start = '2023-01-01'
prefire_end   = '2023-07-31'
postfire_start = '2023-11-01'
postfire_end   = '2023-12-31'

# =========================
# Fungsi koreksi atmosfer DOS1
def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)

# =========================
# Fungsi masking awan
def mask_fmask(image):
    qa = image.select('QA_PIXEL')
    fill    = (1 << 0)
    dilated = (1 << 1)
    cirrus  = (1 << 2)
    cloud   = (1 << 3)
    shadow  = (1 << 4)
    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0))
    return image.updateMask(mask)

# =========================
# Koleksi prefire
prefire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(prefire_start, prefire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
prefire_fill = prefire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
prefire_masked = prefire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
prefire_nbr = prefire_masked.median().unmask(prefire_fill)

# Koleksi postfire
postfire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(postfire_start, postfire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
postfire_fill = postfire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
postfire_masked = postfire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
postfire_nbr = postfire_masked.median().unmask(postfire_fill)

# Hitung dNBR
dnbr = prefire_nbr.subtract(postfire_nbr).rename('dNBR')

# Thresholding: dNBR > 0.5
dnbr_mask = dnbr.gt(0.5).rename('BurnedMask').uint8()


# Visualisasi (putih = terbakar, hitam = tidak terbakar)
mask_vis_params = {
    'min': 0,
    'max': 1,
    'palette': ['000000', 'ffffff']
}

# =========================
# Peta dan tampilan
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dnbr_mask, mask_vis_params, 'Burned Area Mask (dNBR > 0.1)')
m.add_child(folium.LayerControl())

# =========================
# Legenda
legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>Citra Mask 124062</b><br>
<i style="background:rgb(255,255,255);width:12px;height:12px;display:inline-block;margin-right:6px;"></i>Terbakar<br>
<i style="background:rgb(0,0,0);width:12px;height:12px;display:inline-block;margin-right:6px;"></i>Tidak Terbakar<br>
</div>
'''
m.get_root().html.add_child(folium.Element(legend_html))

# Tampilkan
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4db132696220c0e0cbfb272de7aeb467 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;Citra Mask 124062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(255,255,255);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;Terbakar&lt;br&gt;
# &lt;i style=&quot;background:rgb(0,0,0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;Tidak Terbakar&lt;br&gt;
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4db132696220c0e0cbfb272de7aeb467&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4db132696220c0e0cbfb272de7aeb467 = L.map(
#                 &quot;map_4db132696220c0e0cbfb272de7aeb467&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c071204b9742afe89fdf303b187070d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c071204b9742afe89fdf303b187070d8.addTo(map_4db132696220c0e0cbfb272de7aeb467);
#
#
#             var tile_layer_474079d929e0483a97eee43a8a457111 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/9ebbc281703509a2f8471d1767fdb9dd-87207e7410a0e14117b96cc4be91ff95/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_474079d929e0483a97eee43a8a457111.addTo(map_4db132696220c0e0cbfb272de7aeb467);
#
#
#             var layer_control_46b8d6d976d9e885b061b6dbc2ce7d47_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_c071204b9742afe89fdf303b187070d8,
#                 },
#                 overlays :  {
#                     &quot;Burned Area Mask (dNBR \u003e 0.1)&quot; : tile_layer_474079d929e0483a97eee43a8a457111,
#                 },
#             };
#             let layer_control_46b8d6d976d9e885b061b6dbc2ce7d47 = L.control.layers(
#                 layer_control_46b8d6d976d9e885b061b6dbc2ce7d47_layers.base_layers,
#                 layer_control_46b8d6d976d9e885b061b6dbc2ce7d47_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_4db132696220c0e0cbfb272de7aeb467);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 125062

# %%
import ee
import folium
import geemap.foliumap as geemap

# =========================
# Fungsi agar folium bisa menampilkan EE layer
def add_ee_layer(self, ee_image_object, vis_params, name):
    map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
    folium.raster_layers.TileLayer(
        tiles=map_id_dict['tile_fetcher'].url_format,
        attr='Google Earth Engine',
        name=name,
        overlay=True,
        control=True
    ).add_to(self)
folium.Map.add_ee_layer = add_ee_layer

# =========================
# Parameter lokasi dan waktu
path_filter = ee.Filter.eq('WRS_PATH', 125)
row_filter = ee.Filter.eq('WRS_ROW', 62)
pathrow_filter = ee.Filter.And(path_filter, row_filter)

# Prefire dan postfire
prefire_start = '2023-01-01'
prefire_end   = '2023-07-31'
postfire_start = '2023-11-01'
postfire_end   = '2023-12-31'

# =========================
# Fungsi koreksi atmosfer DOS1
def apply_dos1(image):
    bands = ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7']
    corrected = []
    for band in bands:
        band_data = image.select(band)
        dark_object = band_data.reduceRegion(
            reducer=ee.Reducer.percentile([1]),
            geometry=image.geometry(),
            scale=30,
            maxPixels=1e9
        ).getNumber(band)
        corrected_band = band_data.subtract(dark_object).max(0).rename(band)
        corrected.append(corrected_band)
    return image.addBands(ee.Image.cat(corrected), overwrite=True)

# =========================
# Fungsi masking awan
def mask_fmask(image):
    qa = image.select('QA_PIXEL')
    fill    = (1 << 0)
    dilated = (1 << 1)
    cirrus  = (1 << 2)
    cloud   = (1 << 3)
    shadow  = (1 << 4)
    mask = qa.bitwiseAnd(fill).eq(0) \
        .And(qa.bitwiseAnd(dilated).eq(0)) \
        .And(qa.bitwiseAnd(cirrus).eq(0)) \
        .And(qa.bitwiseAnd(cloud).eq(0)) \
        .And(qa.bitwiseAnd(shadow).eq(0))
    return image.updateMask(mask)

# =========================
# Koleksi prefire
prefire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(prefire_start, prefire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
prefire_fill = prefire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
prefire_masked = prefire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
prefire_nbr = prefire_masked.median().unmask(prefire_fill)

# Koleksi postfire
postfire = ee.ImageCollection('LANDSAT/LC09/C02/T1_TOA') \
    .filter(pathrow_filter) \
    .filterDate(postfire_start, postfire_end) \
    .sort('CLOUD_COVER') \
    .map(apply_dos1)
postfire_fill = postfire.map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR')).median()
postfire_masked = postfire.map(mask_fmask).map(lambda img: img.normalizedDifference(['B5', 'B7']).rename('NBR'))
postfire_nbr = postfire_masked.median().unmask(postfire_fill)

# Hitung dNBR
dnbr = prefire_nbr.subtract(postfire_nbr).rename('dNBR')

# Thresholding: dNBR > 0.5
dnbr_mask = dnbr.gt(0.5).rename('BurnedMask').uint8()


# Visualisasi (putih = terbakar, hitam = tidak terbakar)
mask_vis_params = {
    'min': 0,
    'max': 1,
    'palette': ['000000', 'ffffff']
}

# =========================
# Peta dan tampilan
m = folium.Map(location=[-3.3194, 104.7458], zoom_start=8)
m.add_ee_layer(dnbr_mask, mask_vis_params, 'Burned Area Mask (dNBR > 0.1)')
m.add_child(folium.LayerControl())

# =========================
# Legenda
legend_html = '''
<div style="
    position: fixed;
    bottom: 50px;
    right: 10px;
    z-index: 9999;
    background-color: white;
    padding: 10px;
    border: 2px solid grey;
    border-radius: 5px;
    box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
    font-size:14px;
">
<b>Citra Mask 125062</b><br>
<i style="background:rgb(255,255,255);width:12px;height:12px;display:inline-block;margin-right:6px;"></i>Terbakar<br>
<i style="background:rgb(0,0,0);width:12px;height:12px;display:inline-block;margin-right:6px;"></i>Tidak Terbakar<br>
</div>
'''
m.get_root().html.add_child(folium.Element(legend_html))

# Tampilkan
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b98617f9bff7e850418af7b0dde58427 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;
#     position: fixed;
#     bottom: 50px;
#     right: 10px;
#     z-index: 9999;
#     background-color: white;
#     padding: 10px;
#     border: 2px solid grey;
#     border-radius: 5px;
#     box-shadow: 2px 2px 6px rgba(0,0,0,0.3);
#     font-size:14px;
# &quot;&gt;
# &lt;b&gt;Citra Mask 125062&lt;/b&gt;&lt;br&gt;
# &lt;i style=&quot;background:rgb(255,255,255);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;Terbakar&lt;br&gt;
# &lt;i style=&quot;background:rgb(0,0,0);width:12px;height:12px;display:inline-block;margin-right:6px;&quot;&gt;&lt;/i&gt;Tidak Terbakar&lt;br&gt;
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b98617f9bff7e850418af7b0dde58427&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b98617f9bff7e850418af7b0dde58427 = L.map(
#                 &quot;map_b98617f9bff7e850418af7b0dde58427&quot;,
#                 {
#                     center: [-3.3194, 104.7458],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a426c63170ae4f2f5a0bec19e4eb5f34 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a426c63170ae4f2f5a0bec19e4eb5f34.addTo(map_b98617f9bff7e850418af7b0dde58427);
#
#
#             var tile_layer_22219b9625861f1fd6184a4819f7cfeb = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/ee-analafeanalber9/maps/3cfcb9c51e51b25701e0adf990420e20-dd233c2acb2f45ac8655dbf3be9c81d8/tiles/{z}/{x}/{y}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google Earth Engine&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_22219b9625861f1fd6184a4819f7cfeb.addTo(map_b98617f9bff7e850418af7b0dde58427);
#
#
#             var layer_control_3a90f5e8fa7b2d9c8335fc1f5bb2bddb_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a426c63170ae4f2f5a0bec19e4eb5f34,
#                 },
#                 overlays :  {
#                     &quot;Burned Area Mask (dNBR \u003e 0.1)&quot; : tile_layer_22219b9625861f1fd6184a4819f7cfeb,
#                 },
#             };
#             let layer_control_3a90f5e8fa7b2d9c8335fc1f5bb2bddb = L.control.layers(
#                 layer_control_3a90f5e8fa7b2d9c8335fc1f5bb2bddb_layers.base_layers,
#                 layer_control_3a90f5e8fa7b2d9c8335fc1f5bb2bddb_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_b98617f9bff7e850418af7b0dde58427);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
